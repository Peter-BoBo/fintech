# %% [markdown]
# # 웹에서 자료를 수집하는 방법
# * 1. API를 이용해서 자료 수집
#   * naver, google, kakao, 공공데이터에서 제공하는 API를 이용해서 자료 수집
# * 2. Web 페이지를 직접 스크래이핑 해서 자료 수집
#   * 정적페이지 수집: javascript 없이 수집 가능한 사이트
#   * 동적페이지 수집: javascript에 의해서 콘텐츠가 제어. 웹브라우저 제어를 통해 수집

# %%
# 네이버 검색 API 예제 - 책 검색
import os
import sys
import urllib.request
client_id = "_kWwMseeAybz6oDQo3EC"
client_secret = "oWRhEifFRY"
encText = urllib.parse.quote("핀테크")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 31 Mar 2025 11:48:49 +0900",
# 	"total":456065,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>핀테크<\/b> 투자 후기",
# 			"link":"https:\/\/blog.naver.com\/kan1687\/223812724931",
# 			"description":"<b>핀테크<\/b> 투자, 아직도 망설이고 계신가요?  여러분 혹시 이런 고민 해보신 적 있나요? &quot;<b>핀테크<\/b> 분야가 떴다는데, 지금 시작해도 괜찮을까? 좀 더 상황을 지켜봐야 하나?&quot; 사실 이런 생각은 투자를 고민하는 우리... ",
# 			"bloggername":"우정잉♥",
# 			"bloggerlink":"blog.naver.com\/kan1687",
# 			"postdate":"20250329"
# 		},
# 		{
# 			"title":"[<b>핀테크<\/b>] 2024년 <b>핀테크<\/b> 업계 결산: 놀라운 3가지 변화",
# 			"link":"https:\/\/blog.naver.com\/xoom777\/223708685044",
# 			"description":"동안 <b>핀테크<\/b> 업계에는 예상치 못한 변화의 바람이 불었습니다. 한동안 주춤했던 트렌드가... 올 한 해 <b>핀테크<\/b> 업계를 뜨겁게 달군 3가지 트렌드에 대해 자세히 살펴보겠습니다. 암호화폐의 귀환, 기관... ",
# 			"bloggername":"Ich fange an",
# 			"bloggerlink":"blog.naver.com\/xoom777",
# 			"postdate":"20241229"
# 		},
# 		{
# 			"title":"[인사이트 캠퍼스] 2025 동계 <b>핀테크<\/b> 캠프 (with 전주대학교... ",
# ...

# %% [markdown]
# 1. url 주소로 서버에 url과 parameter를 보냄
# 2. 서버로부터 응답을 받음
# 3. 응답코드가 200이면 출력

# %% [markdown]
# ![image.png](attachment:image.png)
#
# def naver(query, display=10, start=1, sort=dim):
#
# 파라미터로 함수 정의

# %% [markdown]
# # url: http://로 시작하는 웹페이지 접속주소
#
# * url: 실제 서비스 서버에 접속하는 주소
# * parameter: 서비스에 요청하는 값
# * https://search.shopping.naver.com/book/search?bookTabType=BEST_SELLER&catId=50005542&pageIndex=1&pageSize=40&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%EB%8F%84%EC%84%9C&sort=REL
# * url: https://search.shopping.naver.com/book/search?
# * parameter: bookTabType=BEST_SELLER&catId=50005542&pageIndex=1&pageSize=40&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%EB%8F%84%EC%84%9C&sort=REL

# %% [markdown]
# 1. url 주소로 서버에 url과 parameter를 보냄
# 2. 서버로부터 응답을 받음
# 3. 응답코드가 200이면 출력

# %% [markdown]
# HTTP 상태 코드
#
# * 200 번대 "OK"
# * 400 번대 "없는 주소"
# * 500 번대 "서버 오류"

# %% [markdown]
# "https://openapi.naver.com/v1/search/blog?query=" + encText<br>
# url + encText라는 파라미터

# %%
data = response_body.decode('utf-8')
data
# Out:
# '{\n\t"lastBuildDate":"Mon, 31 Mar 2025 13:09:44 +0900",\n\t"total":456103,\n\t"start":1,\n\t"display":10,\n\t"items":[\n\t\t{\n\t\t\t"title":"<b>핀테크<\\/b> 투자 후기",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/kan1687\\/223812724931",\n\t\t\t"description":"<b>핀테크<\\/b> 투자, 아직도 망설이고 계신가요?  여러분 혹시 이런 고민 해보신 적 있나요? &quot;<b>핀테크<\\/b> 분야가 떴다는데, 지금 시작해도 괜찮을까? 좀 더 상황을 지켜봐야 하나?&quot; 사실 이런 생각은 투자를 고민하는 우리... ",\n\t\t\t"bloggername":"우정잉♥",\n\t\t\t"bloggerlink":"blog.naver.com\\/kan1687",\n\t\t\t"postdate":"20250329"\n\t\t},\n\t\t{\n\t\t\t"title":"[<b>핀테크<\\/b>] 2024년 <b>핀테크<\\/b> 업계 결산: 놀라운 3가지 변화",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/xoom777\\/223708685044",\n\t\t\t"description":"동안 <b>핀테크<\\/b> 업계에는 예상치 못한 변화의 바람이 불었습니다. 한동안 주춤했던 트렌드가... 올 한 해 <b>핀테크<\\/b> 업계를 뜨겁게 달군 3가지 트렌드에 대해 자세히 살펴보겠습니다. 암호화폐의 귀환, 기관... ",\n\t\t\t"bloggername":"Ich fange an",\n\t\t\t"bloggerlink":"blog.naver.com\\/xoom777",\n\t\t\t"postdate":"20241229"\n\t\t},\n\t\t{\n\t\t\t"title":"[인사이트 캠퍼스] 2025 동계 <b>핀테크<\\/
# ...

# %% [markdown]
# # json으로 변환

# %%
import json

# %%
data = json.loads(data)
# Out:
# {'lastBuildDate': 'Mon, 31 Mar 2025 13:09:44 +0900',
#  'total': 456103,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>핀테크</b> 투자 후기',
#    'link': 'https://blog.naver.com/kan1687/223812724931',
#    'description': '<b>핀테크</b> 투자, 아직도 망설이고 계신가요?  여러분 혹시 이런 고민 해보신 적 있나요? &quot;<b>핀테크</b> 분야가 떴다는데, 지금 시작해도 괜찮을까? 좀 더 상황을 지켜봐야 하나?&quot; 사실 이런 생각은 투자를 고민하는 우리... ',
#    'bloggername': '우정잉♥',
#    'bloggerlink': 'blog.naver.com/kan1687',
#    'postdate': '20250329'},
#   {'title': '[<b>핀테크</b>] 2024년 <b>핀테크</b> 업계 결산: 놀라운 3가지 변화',
#    'link': 'https://blog.naver.com/xoom777/223708685044',
#    'description': '동안 <b>핀테크</b> 업계에는 예상치 못한 변화의 바람이 불었습니다. 한동안 주춤했던 트렌드가... 올 한 해 <b>핀테크</b> 업계를 뜨겁게 달군 3가지 트렌드에 대해 자세히 살펴보겠습니다. 암호화폐의 귀환, 기관... ',
#    'bloggername': 'Ich fange an',
#    'bloggerlink': 'blog.naver.com/xoom777',
#    'postdate': '20241229'},
#   {'title': '[인사이트 캠퍼스] 2025 동계 <b>핀테크</b> 캠프 (with 전주대학교... ',
#    'link': 'https://blog.naver.com/fininsight/223734638126',
# ...

# %%
def text_clean(x):
    result = x.replace("<b>", "").replace("</b>", "")
    return result

# %%
result = {}
for item in data['items']:
    for key, value in item.items():
        value = text_clean(value)
        result.setdefault(key, []).append(value)
result
# Out:
# {'title': ['핀테크 투자 후기',
#   '[핀테크] 2024년 핀테크 업계 결산: 놀라운 3가지 변화',
#   '[인사이트 캠퍼스] 2025 동계 핀테크 캠프 (with 전주대학교... ',
#   '[AI 핀테크] AI와 빅데이터로 금융 시장을 재편하는 핀테크... ',
#   'IPAY 핀테크관련주 ETF -미국 CBDC 코인 서비스 실험 확대',
#   '맨틀 MNT 코인 디파이 핀테크 서비스 소개',
#   '[핀테크 리더] # 2024 금융위원회 선정 10대 기업 _ 1편',
#   '맨틀 네트워크 코인 MNT 핀테크 서비스 등장',
#   '신규 상장 더즌 핀테크 B2B 기업용 금융통신망 쉿 쉿 조용 조용',
#   '테크놀로지스(PGY): AI 기반 대출 혁신의 주목받는 핀테크 기업'],
#  'link': ['https://blog.naver.com/kan1687/223812724931',
#   'https://blog.naver.com/xoom777/223708685044',
#   'https://blog.naver.com/fininsight/223734638126',
#   'https://blog.naver.com/jangpung_/223765345858',
#   'https://blog.naver.com/jaso_/223736810791',
#   'https://blog.naver.com/tmglove/223781181469',
#   'https://blog.naver.com/koreafintech/223675560515',
#   'https://blog.naver.com/ghfjvb465/223781841217',
#   'https://blog.naver.com/2yongki/223805949459',
#   'https://blog.naver.com/an5217/223810108719'],
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)
df
# Out:
#                                        title  \
# 0                                  핀테크 투자 후기
# 1          [핀테크] 2024년 핀테크 업계 결산: 놀라운 3가지 변화
# 2  [인사이트 캠퍼스] 2025 동계 핀테크 캠프 (with 전주대학교...
# 3     [AI 핀테크] AI와 빅데이터로 금융 시장을 재편하는 핀테크...
# 4      IPAY 핀테크관련주 ETF -미국 CBDC 코인 서비스 실험 확대
# 5                   맨틀 MNT 코인 디파이 핀테크 서비스 소개
# 6       [핀테크 리더] # 2024 금융위원회 선정 10대 기업 _ 1편
# 7                  맨틀 네트워크 코인 MNT 핀테크 서비스 등장
# 8       신규 상장 더즌 핀테크 B2B 기업용 금융통신망 쉿 쉿 조용 조용
# 9      테크놀로지스(PGY): AI 기반 대출 혁신의 주목받는 핀테크 기업
#
#                                                link  \
# 0       https://blog.naver.com/kan1687/223812724931
# 1       https://blog.naver.com/xoom777/223708685044
# 2    https://blog.naver.com/fininsight/223734638126
# 3     https://blog.naver.com/jangpung_/223765345858
# 4         https://blog.naver.com/jaso_/223736810791
# 5       https://blog.naver.com/tmglove/223781181469
# 6  https://blog.naver.com/koreafintech/223675560515
# ...

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "_kWwMseeAybz6oDQo3EC"
client_secret = "oWRhEifFRY"
encText = urllib.parse.quote("핀테크")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 31 Mar 2025 13:47:07 +0900",
# 	"total":106,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"핀테크",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32438306822",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3243830\/32438306822.20230920073135.jpg",
# 			"author":"한석주",
# 			"discount":"11400",
# 			"publisher":"커뮤니케이션북스",
# 			"pubdate":"20151101",
# 			"isbn":"9791130441436",
# 			"description":"디지털 기술의 발달은 금융의 모든 것을 바꾸고 있다. 기술 기반의 스타트업들과 비금융권 기업들이 금융 시장에 진입하며 은행을 해체하고 대체해 가는 시대가 오고 있다. 핀테크의 핵심은 기술을 통해 기존의 금융 기관이 제공하지 못했던 부분을 채워 주고, 편의성 증대, 비용 절감, 리스크 분산, 기대 수익 증가 등 고객에게 새로운 가치를 주는 데 있다. 특히 고객들이 쌓은 데이터를 분석해 틈새를 찾아내고 새로운 시장으로 만드는 것이 중요하다. 이 책은 핀테크의 의미와 지급 결제, 대출, 자산관리, 가상 화폐 등 다양한 분야별 성공 사례와 시사점, 오프라인 기업의 대응, 그리고 각국의 핀테크 산업 육성 정책에 대해 살펴본다."
# 		},
# 		{
# 			"title":"핀테크 (IT와 금융이 만나는 새로운 세상)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32506472036",
# ...
