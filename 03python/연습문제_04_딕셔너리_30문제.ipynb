# %% [markdown]
# # 딕셔너리 사용 연습문제 30개
# * 항상 다양한 방식으로 풀어보는 훈련을 해보자 (하드코딩)

# %% [markdown]
# 1. **빈 딕셔너리 `empty_dict`를 생성하고 출력하세요.**

# %%
empty_dict={}
print(empty_dict)
# Out:
# {}

# %%
# dict()
empty_dict = dict()

# %% [markdown]
# 2. **다음과 같은 딕셔너리를 생성하고 출력하세요.**
#    ```python
#    person = {"name": "Alice", "age": 25, "city": "Seoul"}
#
#    ```

# %%
person = {"name": "Alice", "age": 25, "city": "Seoul"}
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
# dict()
# ket = value
person = dict(name="Alice", age=25, city="Seoul")

# %%
# 다중 딕셔너리로 묶을 수 있다
sinbo = dict(name=dict(eng = "Peter", kor="신보"), age=26, city="Seoul")
sinbo
# Out:
# {'name': {'eng': 'Peter', 'kor': '신보'}, 'age': 26, 'city': 'Seoul'}

# %%
# dict([key, value])
person = dict([("name", "Alice"), ("age", 25), ("city", "Seoul")])
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
# dict(zip 묶기)
person = dict(zip(["name", "age", "city"], ["Alice", 25, "Seoul"]))
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %% [markdown]
# 3. **딕셔너리 `person`에서 `"name"` 키의 값을 출력하세요.**
# ```python
# Alice
# ```

# %%
person["name"]
# Out:
# 'Alice'

# %%
# get 메서드
person.get("nam", "key 없음")
# Out:
# 'key 없음'

# %% [markdown]
# 4. **딕셔너리 `person`에서 `"age"` 키의 값을 출력하세요.**
#    ```python
#    25
#    ```

# %%
person["age"]
# Out:
# 25

# %%
# get 메서드
person.get("ag", "key 없음")
# Out:
# 'key 없음'

# %% [markdown]
# 5. **딕셔너리 `person`에 `"job": "Engineer"`를 추가하고 출력하세요.**
#    ```python
#    {"name": "Alice", "age": 25, "city": "Seoul", "job": "Engineer"}
#    ```

# %%
# stedefault 할당
person.setdefault("job", "Engineer")
# Out:
# 'Engineer'

# %%
# 직접 할당
person["job"]="Engineer"
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul', 'job': 'Engineer'}

# %% [markdown]
# 6. **딕셔너리 `person`에서 `"city"`의 값을 `"Busan"`으로 변경하고 출력하세요.**
#    ```python
# {"name": "Alice", "age": 25, "city": "Busan", "job": "Engineer"}
#
#    ```

# %%
# 직접 할당
person["city"]="Busan"
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Busan', 'job': 'Engineer'}

# %%
# update
person.update(city="Busan")

# %% [markdown]
# 7. **딕셔너리 `person`에서 `"age"` 키를 삭제하고 출력하세요.**
#    ```python
#    {"name": "Alice", "city": "Busan", "job": "Engineer"}
#    ```

# %%
# .pop 으로 삭제
person.pop('age')
# Out:
# 25

# %%
# del 로 삭제
del person["age"]
person
# Out:
# {'name': 'Alice', 'city': 'Busan', 'job': 'Engineer'}

# %% [markdown]
# 8. **딕셔너리 `person`의 모든 키를 출력하세요.**
#    ```python
#    dict_keys(['name', 'city', 'job'])
#    ```

# %%
person.keys()
# Out:
# dict_keys(['name', 'city', 'job'])

# %%
# 반복문으로 하나씩 출력

for key in person:
    print(person.get(key, "key 없음"))
# Out:
# Alice
# Busan
# Engineer

# %%
for i in person:
    print(i)
# Out:
# name
# city
# job

# %% [markdown]
# 9. **딕셔너리 `person`의 모든 값(value)을 출력하세요.**
#    ```python
#    dict_values(['Alice', 'Busan', 'Engineer'])
#    ```

# %%
person.values()
# Out:
# dict_values(['Alice', 'Busan', 'Engineer'])

# %%
# 반복문으로 출력
for i in person:
    print(person[i])
# Out:
# Alice
# Busan
# Engineer

# %%
person
# Out:
# {'name': 'Alice', 'city': 'Busan', 'job': 'Engineer'}

# %%
person["name"]
# Out:
# 'Alice'

# %% [markdown]
# 10. **딕셔너리 `person`의 모든 키-값 쌍을 출력하세요.**
#     ```python
#     dict_items([('name', 'Alice'), ('city', 'Busan'), ('job', 'Engineer')])
#     ```

# %%
# items 로 출력
person.items()
# Out:
# dict_items([('name', 'Alice'), ('city', 'Busan'), ('job', 'Engineer')])

# %%
# 반복문으로 key , values 출력
for i in person:
    print(i, person[i])
# Out:
# name Alice
# city Busan
# job Engineer

# %%
# 만약 리스트형으로 출력하고 싶다면?
dict_items = []
for i in person:
    dict_items.append((i, person[i]))
dict_items
# Out:
# [('name', 'Alice'), ('city', 'Busan'), ('job', 'Engineer')]

# %% [markdown]
# 11. **`"email"` 키가 딕셔너리 `person`에 존재하는지 확인하세요.**
#     ```python
#  False
#     ```

# %%
"email" in person
# Out:
# False

# %% [markdown]
# 12.**`person`에서 `"job"`을 제거하고 출력하세요.**
#
# ```python
# "Engineer",
# {'name': 'Alice', 'city': 'Busan'}
# ```

# %%
# del
del person['job']

# %%
person.pop("job")
# Out:
# 'Engineer'

# %% [markdown]
# 13. **`person` 딕셔너리의 모든 키-값 쌍을 초기화하고 출력하세요.**
#     ```python
#     {}
#     ```

# %%
#del person
person={}
person
# Out:
# {}

# %%
# .clear : 리스트, 딕셔너리에서 사용가능
person.clear()

# %%
person
# Out:
# {}

# %% [markdown]
# 14. **중첩 딕셔너리를 student 변수에 생성하고 출력하세요.**
# ```python
# {"name": "Bob",
#  "grades": {"math": 85, "science": 90, "history": 80}
# }
# ```

# %%
student = {"name": "Bob",
 "grades": {"math": 85, "science": 90, "history": 80}
}
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80}}

# %%
# dict()
student =  dict(name="Bob", grades = dict(math = 85, science = 90, history = 80))
student
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80}}

# %% [markdown]
# 15.**student에서 "science" 점수를 출력하세요.**
# ```python
# 90
# ```

# %%
student["grades"]["science"]
# Out:
# 90

# %% [markdown]
# 16. **`student`의 `"grades"`에 `"english": 95`를 추가하고 출력하세요.**
#     ```python
#     {'math': 85, 'science': 90, 'history': 80, 'english': 95}
#     ```

# %%
# dict 함수
student = dict(math=85, science=90, history=80, english=95)

# %%
student["grades"]["english"] = 95
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 85, 'science': 90, 'history': 80, 'english': 95}}

# %%
student["grades"].update(english = 95)

# %% [markdown]
# 17. **`student`의 `"math"` 점수를 88로 변경하고 출력하세요.**
#     ```python
#     {'math': 88, 'science': 90, 'history': 80, 'english': 95}
#     ```

# %%
student.update(math=88)
student['grades']
# Out:
# {'math': 85, 'science': 90, 'history': 80, 'english': 95}

# %%
student['grades'].update(math=88)
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'history': 80, 'english': 95}}

# %% [markdown]
# * 왜 student 출력하면 88점이 나오는데, student['grades'] 출력하면 85점이 나올까요?
# * student의 key를 지정하지 않고(["grades"] X) .update 메서드를 사용하면 math 라는 새로운 키가 생긴단다 ^^

# %% [markdown]
# 18. **`student`에서 `"history"` 점수를 삭제하고 출력하세요.**
#     ```python
#     {'math': 88, 'science': 90, 'english': 95}
#     ```

# %%
del student["grades"]["history"]
student
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}}

# %%
# .pop 이용하기
student["grades"].pop("history")
# Out:
# 80

# %%
student
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}}

# %% [markdown]
# 19. **딕셔너리 `student`에서 setdefault를 이용하여 `"total"`이란 키를 만들고 math, science, english의 합계를 입력하세요. 단, 합계를 구할 때 값을 수동입력 하지 말고 딕셔너리에서 추출해서 더하도록 하세요.**
#     ```python
#     {'name': 'Bob',
#     'grades': {'math': 88, 'science': 90, 'english': 95},
#     'total': 273}
#     ```

# %%
student['grades']['math'] + student['grades']['science'] + student['grades']['english']
# Out:
# 273

# %%
# .values() 사용하기
student['grades'].values()
sum(student['grades'].values())
# Out:
# dict_values([88, 90, 95])

# %%
# .values() 사용해서 setdefault에 삽입하면, 기입 실수를 방지할 수 있다!
student.setdefault('total', sum(student['grades'].values()))
# Out:
# 273

# %%
student.setdefault('total', student['grades']['math'] + student['grades']['science'] + student['grades']['english'])
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'english': 95},
#  'total': 273}

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'english': 95},
#  'total': 273}

# %% [markdown]
# 20. **딕셔너리 `student`에서 update를 이용하여 'english' 는 100, 'history'는 80를 입력하세요.**
# ```python
#  {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'english': 100, 'history': 80},
#  'total': 273}
# ```

# %%
student.update([english])

# %%
student['grades'].update(english = 100, history = 80)
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'english': 100, 'history': 80},
#  'total': 273}

# %% [markdown]
# 21.**courses라는 변수에 dict() 함수를 사용하여 다음과 같은 딕셔너리를 생성하세요.**
# ```python
# {'programming': {'python': 50, 'java': 30, 'Cpp': 20},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}
# ```

# %%
# dict 함수 (따옴표, 콜론 일일이 치면 힘들다)
courses = dict(programming=dict(python=50, java=30, Cpp=20),
               design=dict(Photoshop = 25, Illustrator = 15))

# %%
courses = {'programming': {'python': 50, 'java': 30, 'Cpp': 20},
 'design': {'Photoshop': 25, 'Illustrator': 15}}
print(courses)
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 20}, 'design': {'Photoshop': 25, 'Illustrator': 15}}

# %% [markdown]
# 22. **"python"의 수강생 수를 출력하세요.**
# ```python
# 50
# ```

# %%
courses['programming']['python']
# Out:
# 50

# %% [markdown]
# 23. **딕셔너리 `courses`에서 `"Cpp"` 수강생 수를 25로 변경하고 출력하세요.**
#     ```python
#     {'python': 50, 'java': 30, 'Cpp': 25}
#     ```

# %%
courses['programming']['Cpp']=25
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}

# %%
courses['programming'].update(Cpp=25)
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}

# %% [markdown]
# 24. **딕셔너리 `courses`에서 `"Photoshop"` 수강생 수를 삭제하고 출력하세요.**
#     ```python
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25},
#  'design': {'Illustrator': 15}}
#     ```

# %%
del courses['design']["Photoshop"]
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25},
#  'design': {'Illustrator': 15}}

# %%
# .pop 사용하기
courses['design'].pop('Photoshop')
# Out:
# 25

# %% [markdown]
# 25. **딕셔너리 `courses`에서 `"JavaScript": 40`을 `"programming"` 항목에 추가하고 출력하세요.**
#     ```python
#     {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 40}
#     ```

# %%
courses['programming']["JavaScript"]=40
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 40},
#  'design': {'Illustrator': 15}}

# %%
courses['programming'].update(JavaScript = 40)
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 40},
#  'design': {'Illustrator': 15}}

# %%
# .setdefault 사용하기
courses['programming'].setdefault("JavaScript", 40)

# %% [markdown]
# 26. **딕셔너리 `courses`의 모든 과목명을 출력하세요.**
#     ```python
#     dict_keys(['programming', 'design'])
#     ```

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 courses[key]
#
# KeyError: 'job'

# %%
# courses['programming'].keys()
# courses['design'].keys()

# print(courses['programming'].keys(), courses['design'].keys())
print(list(courses['programming'].keys()) + list(courses['design'].keys()))
# Out:
# ['python', 'java', 'Cpp', 'JavaScript', 'Illustrator']

# %%
# 반복문으로 모든 과목명 출력하기

for key in courses:
#     print(courses[key].keys())
    for subject in courses[key].keys():
        print(subject)
# Out:
# python
# java
# Cpp
# JavaScript
# Illustrator

# %%
#리스트로 변환 후 반복문 출력 (반복문이 젤 어렵넹)

subject_name = []
for key in courses:
#     print(courses[key].keys())
    for subject in courses[key].keys():
        print(subject)
        subject_name.append(subject)
print()        
print(subject_name)
# Out:
# python
# java
# Cpp
# JavaScript
# Illustrator
#
# ['python', 'java', 'Cpp', 'JavaScript', 'Illustrator']

# %% [markdown]
# 27. **딕셔너리 `courses`에서 `"design"` 과목의 모든 정보를 출력하세요.**
#     ```python
#     {'Illustrator': 15}
#     ```

# %%
courses['design'].items()
# Out:
# dict_items([('Illustrator', 15)])

# %% [markdown]
# 28. **딕셔너리 `courses`에서 `"design"` 항목을 삭제하고 전체 딕셔너리를 출력하세요.**
#     ```python
#     {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 40}}
#     ```

# %%
#del courses['design']
print(courses)
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 40}}

# %%
courses.pop(design)

# %% [markdown]
# 29. **딕셔너리 `courses`에서 `"programming"` 항목이 존재하는지 확인하세요.**
#     ```python
#     True
#     ```

# %%
'programming' in courses
# Out:
# True

# %%
"Cpp" in courses["programming"]
# Out:
# True

# %%
# Value "Cpp"를 반복문으로 찾아보자
for key in courses:
    if "Cpp" in key:
        print(True)
    elif "Cpp"in courses[key]:
        print(True)
# Out:
# True

# %% [markdown]
# 30. **딕셔너리 `courses`에서 `"design"` 항목을 출력하고 `"design"` 이 없다면 design key 없음 이라고 출력하도록 하세요.**
# ```python
# design key 없음
# ```

# %%
courses.get("design", "design key 없음")
# Out:
# 'design key 없음'
