# %% [markdown]
# # if else 조건문

# %% [markdown]
# ## 1. 조건문이란? 특정 조건을 판별해서 작업을 분기시키는 문법
# if 조건식:<br>
# ____조건이 참일 때 실행할 코드<br>
# else:<br>
# ____조건이 거짓일 때 실행할 코드

# %%
x = 13

# %%
if x==10:
    print(f"x는, {x}입니다.")
else:
    print(f"{x}는, 10이 아닙니다.")
# Out:
# 13는, 10이 아닙니다.

# %%
l1 = ['파이썬', "조건문", 10, 15.3, True, [1,2,3], (4,5,6), {"key : value (3,6,5)"}]

# %%
if "파이썬" not in l1:
    print("li안에 파이썬이 없습니다.")
else:
    print("l1안에 파이썬이 있습니다")
# Out:
# l1안에 파이썬이 있습니다

# %% [markdown]
# * 숫자를 입력받아 홀수인지 짝수인지 판단하는 프로그램

# %%
x = input("숫자를 입력하세요")
if int(x) % 2 == 0:
    print(f"입력한 숫자 {x}는 짝수입니다.")
else:
    print(f"입력한 숫자 {x}는 홀수입니다.")
# Out:
# 숫자를 입력하세요1568
# 입력한 숫자 1568는 짝수입니다.

# %%
x=4
x
# Out:
# 8

# %%
x = int(input())

if 0 <= x <= 10:
    print(f"{x}는 0에서 10사이에 있는 숫자 입니다.")
else:
    print(f"{x}는 0에서 10사이에 있는 숫자가 아닙니다.")
# Out:
# 11
# 11는 0에서 10사이에 있는 숫자가 아닙니다.

# %%
x = int(input())

if 0 <= x <= 10 and x %2 == 0:
    print(f"{x}는 0에서 10사이에 있는 숫자이고 짝수입니다.")
else:
    print(f"{x}는 0에서 10사이에 있는 숫자가 아니고 홀수입니다.")
# Out:
# 8
# 8는 0에서 10사이에 있는 숫자이고 짝수입니다.

# %% [markdown]
# ## 2. 다중 조건문 사용하기 elif
# if 조건식:<br>
# ____조건이 참일 때 실행할 코드<br>
# elif 조건식2:<br>
# ____조건식2가 참일 때 실행할 코드<br>
# elif 조건식3:<br>
# ____조건식3이 참일 때 실행할 코드<br>
# else:<br>
# ____조건식 1,2,3이 모두 거짓일 때 실행할 코드

# %% [markdown]
# * 점수를 입력받아서 81-100 A, 61-80 B, 40-60 C, 21-40 D, 0-20 F 등급

# %%
score = int(input("점수를 입력하세요"))

if 0 <= score <=100:
    if 0 <= score <= 20:
        print(f"{score}는 F등급 입니다.")
    elif 21 <= score <= 40:
        print(f"{score}는 D등급 입니다.")
    elif 41 <= score <= 60:
        print(f"{score}는 C등급 입니다.")
    elif 61<= score <= 80:
        print(f"{score}는 B등급 입니다.")
    elif 81 <= score <= 100:
        print(f"{score}는 A등급 입니다.")
else:
    print("숫자를 0-100사이로 입력해 주세요")
# Out:
# 점수를 입력하세요44
# 44는 C등급 입니다.

# %% [markdown]
# * 1-50사이의 숫자를 입력 받아서 3의 배수면 3의 배수입니다. 3의 배수가 아니면 3의 배수가 아닙니다.
#   * 입력받기, 정수로 변환하기
#   * 1-50 사이의 숫자인가?
#   * 3의 배수인가? %3 == 0
#   * 출력

# %%
num = int(input("정수로 숫자를 입력하세요"))
    
if 1 <= num <=50:
    if num % 3 == 0:
      print("3의 배수입니다.")
    elif num %3 != 0:
      print("3의 배수가 아닙니다")
else:
    print("1-50 사이의 숫자를 입력해주세요.")
# Out:
# 정수로 숫자를 입력하세요21
# 3의 배수입니다.

# %%
num = int(input("정수로 숫자를 입력하세요"))
#print(num, type(num))
    
if 1 <= num <=50:
    #print("숫자가 1-50사이의 정수입니다/")
    if num % 3 == 0:
        print(f"{num}은 3의 배수입니다")
    else:
        print(f"{num}은 3의 배수가 아닙니다.")
else:
    print("숫자를 1-50사이의 정수로 입력해 주세요.")
    
# 늘 중간중간마다 print()로 확인하는 습관을 들이자!
# type()로 확인하는 습관도!
# Out:
# 정수로 숫자를 입력하세요50
# 50은 3의 배수가 아닙니다.

# %% [markdown]
# ## 3. 조건 표현식
# * 참일 때 실행코드 if조건else 거짓일 때 실행 코드

# %%
num = int(input("숫자를 입력하세요"))
#print(num, type(num))
if num %2 == 0:
    print("짝수")
else:
    print("홀수")
# Out:
# 숫자를 입력하세요12
# 짝수

# %%
# 조건 표현식
num = int(input("숫자를 입력하세요"))
#print(num, type(num))
print("짝수") if num % 2 == 0 else print("홀수")
# Out:
# 숫자를 입력하세요151
# 홀수
