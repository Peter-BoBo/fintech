# %% [markdown]
# # 셀복사:h1
# ## h2
# ### h3
# * 목록
# * 목록2
#     * 세부목록1
#            *세부목록의 목록<br>
# <ul>
#     <li>목록1</li>
#     <li>목록1</li>
# </ul>
#
# <h1>제목3</h1>
#
# ### 링크걸기
# [네이버링크](https://naver.com)
#
# ### 이미지 넣기
# ![강아지](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.dongascience.com%2Fnews.php%3Fidx%3D35340&psig=AOvVaw0bHibwXHUSj0LOnZshUBdN&ust=1741833027856000&source=images&cd=vfe&opi=89978449&ved=0CBQQjRxqFwoTCIji5uu_g4wDFQAAAAAdAAAAABAK)
#
# # 수식넣기
# $$ A \over B $$
#
# # 표만들기
# |제목|내용|설명|
# |------|---|---|
# |테스트1|테스트2|테스트3|
# |테스트1|테스트2|테스트3|
# |테스트1|테스트2|테스트3|

# %%
a = 1

# %%
b = 2

# %%
a + b
# Out:
# 3
