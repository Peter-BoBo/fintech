# %% [markdown]
# # 판다스 1일차

# %% [markdown]
# # pandas

# %%
# pip install pandas
# conda install pandas

# %% [markdown]
# * numpy를 내부적으로 활용함
# * 데이터 분석에 특화된 데이터 구조 제공(테이블, dataframe)
# * 다양한 데이터 분석 함수 제공
# * 데이터베이스에 쉽게 연결 가능
# * json 데이터 html의 table 요소를 dataframe으로 손쉽게 변형 가능
# * **numpy와 달리 pandas는 2차원만 다룬다**
# * **데이터 분석시 가장 많이 사용할 라이브러리**

# %% [markdown]
# # pandas에서 다루는 데이터 타입 2가지
# ## 1) DataFrame: 2차원의 표형식 데이터
# * python의 dict와도 비슷. 하나의 key에 list 형태의 value가 매칭되어 있는 형태
# * {key : [value1, value2, value3], key2 : [value1, value2, value3]}
# ## 2) Series: 1차원의 벡터형식 데이터
# * python의 list, tuple, ndarray의 1차원 상태와 비슷
# * DataFrame에서 한 컬럼만 잘라오면 '시리즈'

# %%
import pandas as pd

# %% [markdown]
# # 데이터프레임 만들기
# pd.DataFrame({key1: [value1, value2] key2:[value1, value2]})

# %%
df = pd.DataFrame(
        {'이름': ['홍길동', '둘리', '또치', '도우너'],
         '주소': ['서울', '의정부', '고양', '성남'],
         '취미': ['음악감상', '놀기', '달리기', '바이올린']}
         )

# %%
df
# Out:
#     이름   주소    취미
# 0  홍길동   서울  음악감상
# 1   둘리  의정부    놀기
# 2   또치   고양   달리기
# 3  도우너   성남  바이올린

# %%
df.shape
# Out:
# (4, 3)

# %%
df.ndim
# Out:
# 2

# %%
# 시리즈
df['이름']
# Out:
# 0    홍길동
# 1     둘리
# 2     또치
# 3    도우너
# Name: 이름, dtype: object

# %%
df['이름'].dtype
# Out:
# dtype('O')

# %%
print(type(tuple(df['이름'][:2])))
# Out:
# <class 'tuple'>

# %% [markdown]
# # Serires 만들기
# * pd.Series([리스트 자료/튜플], name="컬럼명")
# * 이름을 가지고 있는 list / 벡터
# * DataFrame에서 컬럼 1개를 잘라온 형태

# %%
ages = pd.Series([22, 53, 35], name="나이")

# %%
ages
# Out:
# 0    22
# 1    53
# 2    35
# Name: 나이, dtype: int64

# %%
ages.dtype
# Out:
# dtype('int64')

# %%
ages[0:2]
# Out:
# 0    22
# 1    53
# Name: 나이, dtype: int64

# %%
ages.min
# Out:
# <bound method Series.min of 0    22
# 1    53
# 2    35
# Name: 나이, dtype: int64>

# %%
ages.max()
# Out:
# np.int64(53)

# %%
ages.sum()
# Out:
# np.int64(110)

# %%
ages.cumsum()
# Out:
# 0     22
# 1     75
# 2    110
# Name: 나이, dtype: int64

# %%
ages.mean()
# Out:
# np.float64(36.666666666666664)

# %%
ages.median()
# Out:
# np.float64(35.0)

# %% [markdown]
# # 판다스에서 자료 불러오기, 저장하기
# * csv, tsv, excel, json, html, sql
# * pd.read_확장자명(파일경로, 옵션)

# %% [markdown]
# excel 파일 불러오기

# %%
df_excel = pd.read_excel("./data/Online Retail.xlsx")
df_excel
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# %%time
df_excel2 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx", header=12, usecols=[1,2,3,4,5])
# Out:
# C:\Users\Admin\miniforge3\envs\fintech\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# CPU times: total: 16.4 s
# Wall time: 16.5 s

# %%
df_excel2
# Out:
#                        시군구      번지    본번  부번                단지명
# 0         서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차
# 1      강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)
# 2        대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안
# 3             광주광역시 남구 진월동   312-7   312   7                 광명
# 4             광주광역시 남구 진월동  331-93   331  93                 중흥
# ...                    ...     ...   ...  ..                ...
# 37575        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지
# 37576        부산광역시 사상구 모라동     552   552   0               백양그린
# 37577        광주광역시 광산구 비아동   152-5   152   5                 호반
# 37578        부산광역시 사상구 모라동     552   552   0               백양그린
# 37579         대구광역시 북구 읍내동  1366-2  1366   2               칠곡보성
#
# [37580 rows x 5 columns]

# %%
# %%time
df_csv = pd.read_csv("./data/아파트(매매)_실거래가_20240806113828.csv")
df_csv
# Out:
# CPU times: total: 141 ms
# Wall time: 190 ms
# <timed exec>:1: DtypeWarning: Columns (0,3,4,6,7,8,11,14) have mixed types. Specify dtype option on import or set low_memory=False.
#       □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.     Unnamed: 1  \
# 0      □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...            NaN
# 1      □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...            NaN
# 2      □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...            NaN
# 3                                                    NaN            NaN
# 4      * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 콜센터 1533-29...            NaN
# ...                                                  ...            ...
# 37587                                              37576  서울특별시 송파구 장지동
# 37588                                              37577  부산광역시 사상구 모라동
# 37589                                              37578  광주광역시 광산구 비아동
# 37590                                              37579  부산광역시 사상구 모라동
# 37591                                              37580   대구광역시 북구 읍내동
#
#       Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0            NaN        NaN        NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN        NaN        NaN
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 37587        849        849          0  송파파인타운3단지      84.98     202407
# 37588        552        552          0       백양그린       41.3     202407
# 37589      152-5        152          5         호반      59.88     202407
# 37590        552        552          0       백양그린       41.3     202407
# 37591     1366-2       1366          2       칠곡보성      84.98     202407
#
#       Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0            NaN        NaN  ...         NaN         NaN         NaN
# 1            NaN        NaN  ...         NaN         NaN         NaN
# 2            NaN        NaN  ...         NaN         NaN         NaN
# 3            NaN        NaN  ...         NaN         NaN         NaN
# 4            NaN        NaN  ...         NaN         NaN         NaN
# ...          ...        ...  ...         ...         ...         ...
# 37587          1    117,500  ...          14          개인          개인
# 37588          1      7,000  ...           8          개인          개인
# 37589          1     15,400  ...           5          개인          개인
# 37590          1      7,500  ...          10          개인          개인
# 37591          1     21,000  ...           9          개인          개인
#
#       Unnamed: 14  Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0             NaN          NaN         NaN         NaN         NaN
# 1             NaN          NaN         NaN         NaN         NaN
# 2             NaN          NaN         NaN         NaN         NaN
# 3             NaN          NaN         NaN         NaN         NaN
# 4             NaN          NaN         NaN         NaN         NaN
# ...           ...          ...         ...         ...         ...
# 37587        2008      충민로 152           -        중개거래      서울 송파구
# 37588        1992  모라로110번길 88           -        중개거래      부산 사상구
# 37589        1998      비아로 185           -        중개거래      광주 광산구
# 37590        1992  모라로110번길 88           -        중개거래      부산 사상구
# 37591        1992    구암로21길 26           -        중개거래       대구 북구
#
#       Unnamed: 19 Unnamed: 20
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 37587           -         아파트
# 37588    24.07.10         아파트
# 37589    24.07.26         아파트
# 37590    24.07.19         아파트
# 37591           -         아파트
#
# [37592 rows x 21 columns]

# %%
df_json = pd.read_json("./data/서울특별시_관광지입장정보_2011_2016.json")
df_json
# Out:
#     ForNum  NatNum  addrCd gungu      resNm  rnum   sido  yyyymm
# 0    44722   75991    1111   종로구        창덕궁     1  서울특별시  201112
# 1        0   11017    1111   종로구        운현궁     2  서울특별시  201112
# 2   132399  237330    1111   종로구        경복궁     3  서울특별시  201112
# 3     3133   21267    1111   종로구        창경궁     4  서울특별시  201112
# 4    18226   24223    1111   종로구         종묘     5  서울특별시  201112
# ..     ...     ...     ...   ...        ...   ...    ...     ...
# 62    5588   44232    1141  서대문구  서대문형무소역사관     8  서울특별시  201512
# 63       0   22587    1141  서대문구  서대문자연사박물관     9  서울특별시  201512
# 64   29520    8822    1144   마포구    트릭아이미술관    10  서울특별시  201512
# 65       3    1647    1165   서초구      헌릉ㆍ인릉    11  서울특별시  201512
# 66     492   14454    1168   강남구      선릉·정릉    12  서울특별시  201512
#
# [67 rows x 8 columns]

# %%
df_html = pd.read_html("./data/corpList.htm")
df_html[0]
# Out:
#     Unnamed: 0                             Unnamed: 1  \
# 0     한국제15호스팩                             금융 지원 서비스업
# 1       에스오에스랩  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2   미래에셋비전스팩6호                             금융 지원 서비스업
# 3   에이치엠씨제7호스팩                             금융 지원 서비스업
# 4        파라다이스                     유원지 및 기타 오락관련 서비스업
# 5       한중엔시에스      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 6     KB제29호스팩                             금융 지원 서비스업
# 7   미래에셋비전스팩5호                             금융 지원 서비스업
# 8     씨어스테크놀로지                             의료용 기기 제조업
# 9     한국제14호스팩                             금융 지원 서비스업
# 10   디비금융스팩12호                                 기타 금융업
# 11        라메디텍                             의료용 기기 제조업
# 12       그리드위즈                 그외 기타 전문, 과학 및 기술 서비스업
# 13       다원넥스뷰                        사진장비 및 광학기기 제조업
# 14  미래에셋비전스팩4호                             금융 지원 서비스업
#
#                                            Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                                              기업인수합병  2024-06-26        12월
# 1                                산업용 및 차량용 라이다(LiDAR)  2024-06-25        12월
# 2                                              기업인수합병  2024-06-24        12월
# 3                                                기타금융  2024-06-24        12월
# 4                                      카지노, 호텔, 복합리조트  2024-06-24        12월
# 5   수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV ...  2024-06-24        12월
# 6                                              기업인수합병  2024-06-21        12월
# 7                                              기업인수합병  2024-06-19        12월
# 8                                심전도검사솔루션 입원환자모니터링솔루션  2024-06-19        12월
# 9                                              기업인수합병  2024-06-19        12월
# 10                                          기업인수 및 합병  2024-06-18        12월
# 11                                초소형 레이저 의료기기 및 미용기기  2024-06-17        12월
# 12                             수요관리 서비스, 전기차 충전기 모뎀 등  2024-06-14        12월
# 13                   LSMB(Laser Micro Bonding System)  2024-06-11        12월
# 14                                  기업인수목적회사(기타금융서비스)  2024-05-29        12월
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0          유한        NaN      서울특별시
# 1         정지성    홈페이지 보기      광주광역시
# 2         정명훈        NaN      서울특별시
# 3         강신명        NaN      서울특별시
# 4       최종환..    홈페이지 보기      서울특별시
# 5         김환식    홈페이지 보기       경상북도
# 6         서영화        NaN      서울특별시
# 7         김대호        NaN      서울특별시
# 8         이영신    홈페이지 보기        경기도
# 9         변성환        NaN      서울특별시
# 10        김창희        NaN      서울특별시
# 11        최종석        NaN      서울특별시
# 12        김구환    홈페이지 보기        경기도
# 13        남기중    홈페이지 보기        경기도
# 14        김정수        NaN      서울특별시

# %% [markdown]
# DB에서 자료 읽어오기

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/exchange_rate")
conn = engine.connect()
df_sql = pd.read_sql("exchange_rate", con=conn)
conn.close()
df_sql
# Out:
#             date            통화  현찰_사실_때_환율  현찰_사실_때_Spread  현찰_파실_때_환율  \
# 0     1995-01-03        미국 USD      800.53             1.5      776.87
# 1     1995-01-03  일본 JPY (100)      798.89             1.5      775.29
# 2     1995-01-03        유로 EUR        0.00             0.0        0.00
# 3     1995-01-03        중국 CNY        0.00             0.0        0.00
# 4     1995-01-03        홍콩 HKD      103.45             3.0      100.41
# ...          ...           ...         ...             ...         ...
# 33848 2025-04-15       리비아 LYD        0.00             0.0        0.00
# 33849 2025-04-15      루마니아 RON        0.00             0.0        0.00
# 33850 2025-04-15       미얀마 MMK        0.00             0.0        0.00
# 33851 2025-04-15     에티오피아 ETB        0.00             0.0        0.00
# 33852 2025-04-15    우즈베키스탄 UZS        0.00             0.0        0.00
#
#        현찰_파실_때_Spread  송금_보낼_때_보낼_때  송금_받을_때_받을_때  외화_수표_파실때  매매_기준율  환가_료율  \
# 0                 1.5        791.80        785.60       0.00  788.70   0.00
# 1                 1.5        791.81        782.37       0.00  787.09   0.00
# 2                 0.0        975.40        959.92     957.94  967.66   7.37
# 3                 0.0         94.12          0.00       0.00   93.38   1.00
# 4                 3.0        102.74        101.12       0.00  101.93   0.00
# ...               ...           ...           ...        ...     ...    ...
# 33848             0.0        260.07        254.93       0.00  257.50   0.00
# 33849             0.0        329.99        322.81       0.00  326.40   7.74
# 33850             0.0          0.00          0.00       0.00    0.68   0.00
# 33851             0.0          0.00          0.00       0.00   10.81   0.00
# 33852             0.0          0.00          0.00       0.00    0.11   0.00
#
#        미화_환산율
# 0      1.0000
# 1      0.9980
# 2      1.2269
# 3      0.1184
# 4      0.1292
# ...       ...
# 33848  0.1799
# 33849  0.2280
# 33850  0.0005
# 33851  0.0076
# 33852  0.0001
#
# [33853 rows x 12 columns]

# %% [markdown]
# # 타이타닉 데이터셋으로 pandas 기능 익히기

# %%
engine = create_engine("mysql+pymysql://kict01:kict01@221.155.18.165:3306/titanic")
conn = engine.connect()
df_sql = pd.read_sql("p_info", con=conn)
conn.close()
df_sql
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch
# 0    22.0      1      0
# 1    38.0      1      0
# 2    26.0      0      0
# 3    35.0      1      0
# 4    35.0      0      0
# ..    ...    ...    ...
# 886  27.0      0      0
# 887  19.0      0      0
# 888   NaN      1      2
# 889  26.0      0      0
# 890  32.0      0      0
#
# [891 rows x 6 columns]

# %%
df = pd.read_csv("./data/Taitanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# * 데이터의 일부만 보기
# * 앞쪽 head(), 뒷쪽 tail()
# * 기본 값은 5행

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.tail(1)
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
# 데이터프레임의 각 컬럼 데이터타입
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # .info
# * 컬럼명, null이 아닌 데이터 개수, 데이터타입을 동시에 출력

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# # .describe()
# * 데이터 프레임의 숫자 데이터의 기초통계를 보여주는 함수
# * count, mean, std, min, 25%, 50%, 75%, max

# %%
# include=all : 모든 열 출력
# include=['object']  # 문자열 열만
# include=['number']  # 숫자 열만
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# count   714.000000  891.000000  891.000000     891  891.000000   204      889
# unique         NaN         NaN         NaN     681         NaN   147        3
# top            NaN         NaN         NaN  347082         NaN    G6        S
# freq           NaN         NaN         NaN       7         NaN     4      644
# mean     29.699118    0.523008    0.381594     NaN   32.204208   NaN      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429   NaN      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000   NaN      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400   NaN      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200   NaN      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000   NaN      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200   NaN      NaN

# %%
# 숫자형 열만 요약
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 판다스 데이터 프레임에서 일부 자료만 추출하기

# %% [markdown]
# * 데이터프레임에서 1개 컬럼만 가져오기

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(type(df['Name']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df[['Age','Name']]
# Out:
#       Age                                               Name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886  27.0                              Montvila, Rev. Juozas
# 887  19.0                       Graham, Miss. Margaret Edith
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0                              Behr, Mr. Karl Howell
# 890  32.0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df[['Age', 'Name', 'Pclass']]
# Out:
#       Age                                               Name  Pclass
# 0    22.0                            Braund, Mr. Owen Harris       3
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2    26.0                             Heikkinen, Miss. Laina       3
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4    35.0                           Allen, Mr. William Henry       3
# ..    ...                                                ...     ...
# 886  27.0                              Montvila, Rev. Juozas       2
# 887  19.0                       Graham, Miss. Margaret Edith       1
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"       3
# 889  26.0                              Behr, Mr. Karl Howell       1
# 890  32.0                                Dooley, Mr. Patrick       3
#
# [891 rows x 3 columns]

# %% [markdown]
# * 데이터프레임의 컬럼 순서 바꾸기

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 복수 컬럼  선택시, 이중 대괄호 사용
df[['Survived','Pclass','Name','Sex', 'Sex', 'Age','Embarked', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'PassengerId']]
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex     Sex   Age Embarked  SibSp  Parch            Ticket     Fare  \
# 0      male    male  22.0        S      1      0         A/5 21171   7.2500
# 1    female  female  38.0        C      1      0          PC 17599  71.2833
# 2    female  female  26.0        S      0      0  STON/O2. 3101282   7.9250
# 3    female  female  35.0        S      1      0            113803  53.1000
# 4      male    male  35.0        S      0      0            373450   8.0500
# ..      ...     ...   ...      ...    ...    ...               ...      ...
# 886    male    male  27.0        S      0      0            211536  13.0000
# 887  female  female  19.0        S      0      0            112053  30.0000
# 888  female  female   NaN        S      1      2        W./C. 6607  23.4500
# 889    male    male  26.0        C      0      0            111369  30.0000
# 890    male    male  32.0        Q      0      0            370376   7.7500
#
#     Cabin  PassengerId
# 0     NaN            1
# 1     C85            2
# 2     NaN            3
# 3    C123            4
# 4     NaN            5
# ..    ...          ...
# 886   NaN          887
# 887   B42          888
# 888   NaN          889
# 889  C148          890
# 890   NaN          891
#
# [891 rows x 13 columns]

# %% [markdown]
# 기존 데이터프레임
# ![image.png](attachment:image.png)

# %% [markdown]
# # 데이터프레임에서 일부 컬럼만 가져오기2
# * loc: 인덱스 이름과 컬럼명으로 데이터의 일부를 추출해 가져옴
#   * df.loc[시작행인덱스, 끝행인덱스, ['컬럼명1', '컬럼명2']]
# * iloc: 인덱스를 이용해 슬라이싱으로 데이터의 일부를 가져옴
#   * df.iloc[시작row_index : 끝 row_index, 시작_column_index : 끝_column_index]

# %% [markdown]
# ## loc[시작행인덱스, 끝행인덱스, ['컬럼명1', '컬럼명2']]

# %%
df.loc[100:130, ['Name', 'Age']]
# Out:
#                                   Name   Age
# 100            Petranec, Miss. Matilda  28.0
# 101   Petroff, Mr. Pastcho ("Pentcho")   NaN
# 102          White, Mr. Richard Frasar  21.0
# 103         Johansson, Mr. Gustaf Joel  33.0
# 104     Gustafsson, Mr. Anders Vilhelm  37.0
# 105              Mionoff, Mr. Stoytcho  28.0
# 106   Salkjelsvik, Miss. Anna Kristine  21.0
# 107             Moss, Mr. Albert Johan   NaN
# 108                    Rekic, Mr. Tido  38.0
# 109                Moran, Miss. Bertha   NaN
# 110     Porter, Mr. Walter Chamberlain  47.0
# 111               Zabour, Miss. Hileni  14.5
# 112             Barton, Mr. David John  22.0
# 113            Jussila, Miss. Katriina  20.0
# 114              Attalah, Miss. Malake  17.0
# 115              Pekoniemi, Mr. Edvard  21.0
# 116               Connors, Mr. Patrick  70.5
# 117    Turpin, Mr. William John Robert  29.0
# 118           Baxter, Mr. Quigg Edmond  24.0
# 119  Andersson, Miss. Ellis Anna Maria   2.0
# 120        Hickman, Mr. Stanley George  21.0
# 121         Moore, Mr. Leonard Charles   NaN
# 122               Nasser, Mr. Nicholas  32.5
# 123                Webber, Miss. Susan  32.5
# 124        White, Mr. Percival Wayland  54.0
# 125       Nicola-Yarred, Master. Elias  12.0
# 126                McMahon, Mr. Martin   NaN
# 127          Madsen, Mr. Fridtjof Arne  24.0
# 128                  Peter, Miss. Anna   NaN
# 129                 Ekstrom, Mr. Johan  45.0
# 130               Drazenoic, Mr. Jozef  33.0

# %%
df.loc[109, ['Age']]
# Out:
# Age    NaN
# Name: 109, dtype: object

# %%
df.loc[101, ['Age']] = 29

# %%
print(df.loc[101:102, ['Name', 'Age']])
display(df.loc[101:102, ['Name', 'Age']])
# print(type(df.loc[101, ['Name', 'Age']]))
# Out:
#                                  Name   Age
# 101  Petroff, Mr. Pastcho ("Pentcho")  29.0
# 102         White, Mr. Richard Frasar  21.0
#                                  Name   Age
# 101  Petroff, Mr. Pastcho ("Pentcho")  29.0
# 102         White, Mr. Richard Frasar  21.0

# %%
static = df.describe()
print(type(static))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
static
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 시작/끝 인덱스는 숫자만 지정 X, 문자열도 가능

static.loc['min':'max', ['PassengerId', 'Age']]
# Out:
#      PassengerId     Age
# min          1.0   0.420
# 25%        223.5  20.125
# 50%        446.0  28.000
# 75%        668.5  38.000
# max        891.0  80.000

# %%
# 75% + ((75%-25%) * 1.5)
static.loc['75%'] + ((static.loc['75%'] - static.loc['25%'] * 1.5))
# Out:
# PassengerId    1001.7500
# Survived          2.0000
# Pclass            3.0000
# Age              45.8125
# SibSp             2.0000
# Parch             0.0000
# Fare             50.1344
# dtype: float64

# %% [markdown]
# #### df.iloc[시작row_index : 끝 row_index, 시작_column_index : 끝_column_index]

# %%
# 끝 index -1
df.iloc[0:10, 0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
df.iloc[4:11, -5:]
# Out:
#     Parch   Ticket     Fare Cabin Embarked
# 4       0   373450   8.0500   NaN        S
# 5       0   330877   8.4583   NaN        Q
# 6       0    17463  51.8625   E46        S
# 7       1   349909  21.0750   NaN        S
# 8       2   347742  11.1333   NaN        S
# 9       0   237736  30.0708   NaN        C
# 10      1  PP 9549  16.7000    G6        S

# %%
df.iloc[4, 4] = 'female'

# %%
df.iloc[4, 4]
# Out:
# 'female'

# %%
df.iloc[:10:2, ::2]
# Out:
#    PassengerId  Pclass     Sex  SibSp            Ticket Cabin
# 0            1       3    male      1         A/5 21171   NaN
# 2            3       3  female      0  STON/O2. 3101282   NaN
# 4            5       3  female      0            373450   NaN
# 6            7       1    male      0             17463   E46
# 8            9       3  female      0            347742   NaN

# %%
static.iloc[4:7, [1,2,5]]
# Out:
#      Survived  Pclass  Parch
# 25%       0.0     2.0    0.0
# 50%       0.0     3.0    0.0
# 75%       1.0     3.0    0.0

# %% [markdown]
# * 특정 컬럼에서 유일값(중복되지 않은 고유한 값) 출력하기
# * .unique()

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# * .nunique()
# * 유일값의 개수를 출력
# * nan 값은 무시

# %%
df['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# * 카테고리 컬럼에서 유일값 별 개수를 세는 함수
# * value_counts()

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# ascending 옵션 value의 개수에 따라서 오름차순, 내림차순 정렬
df['Pclass'].value_counts(ascending = True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts(sort = True)
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Age'].value_counts(sort = False)
# Out:
# Age
# 22.00    27
# 38.00    11
# 26.00    18
# 35.00    18
# 54.00     8
#          ..
# 0.67      1
# 30.50     2
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Age'].value_counts(sort = False)
# Out:
# Age
# 22.00    27
# 38.00    11
# 26.00    18
# 35.00    18
# 54.00     8
#          ..
# 0.67      1
# 30.50     2
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# * 데이터를 정렬하는 함수
# * sort_values(by="컬럼명")
# * order by

# %%
df.sort_values(by='Age', ascending = False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 630    male  80.0      0      0       27042  30.0000   A23        S
# 851    male  74.0      0      0      347060   7.7750   NaN        S
# 493    male  71.0      0      0    PC 17609  49.5042   NaN        C
# 96     male  71.0      0      0    PC 17754  34.6542    A5        C
# 116    male  70.5      0      0      370369   7.7500   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 859    male   NaN      0      0        2629   7.2292   NaN        C
# 863  female   NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male   NaN      0      0      345777   9.5000   NaN        S
# 878    male   NaN      0      0      349217   7.8958   NaN        S
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [891 rows x 12 columns]

# %% [markdown]
# * 기준컬럼 2개로 정렬할 때

# %%
df.sort_values(by=['Pclass' ,  'Age'], ascending = False)
# Out:
#      PassengerId  Survived  Pclass  \
# 851          852         0       3
# 116          117         0       3
# 280          281         0       3
# 483          484         1       3
# 326          327         0       3
# ..           ...       ...     ...
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 851                           Svensson, Mr. Johan    male  74.0      0      0
# 116                          Connors, Mr. Patrick    male  70.5      0      0
# 280                              Duane, Mr. Frank    male  65.0      0      0
# 483                        Turkula, Mrs. (Hedwig)  female  63.0      0      0
# 326                     Nysveen, Mr. Johan Hansen    male  61.0      0      0
# ..                                            ...     ...   ...    ...    ...
# 766                     Brewe, Dr. Arthur Jackson    male   NaN      0      0
# 793                      Hoyt, Mr. William Fisher    male   NaN      0      0
# 815                              Fry, Mr. Richard    male   NaN      0      0
# 839                          Marechal, Mr. Pierre    male   NaN      0      0
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1      0
#
#        Ticket     Fare Cabin Embarked
# 851    347060   7.7750   NaN        S
# 116    370369   7.7500   NaN        Q
# 280    336439   7.7500   NaN        Q
# 483      4134   9.5875   NaN        S
# 326    345364   6.2375   NaN        S
# ..        ...      ...   ...      ...
# 766    112379  39.6000   NaN        C
# 793  PC 17600  30.6958   NaN        C
# 815    112058   0.0000  B102        S
# 839     11774  29.7000   C47        C
# 849     17453  89.1042   C92        C
#
# [891 rows x 12 columns]

# %% [markdown]
# * 컬럼을 인덱스로 지정하기
# * set_index("컬럼명")

# %%
df = df.set_index(["PassengerId", "Name"])
df
# Out:
#                                                                 Survived  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                    0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...         1
# 3           Heikkinen, Miss. Laina                                     1
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)               1
# 5           Allen, Mr. William Henry                                   0
# ...                                                                  ...
# 887         Montvila, Rev. Juozas                                      0
# 888         Graham, Miss. Margaret Edith                               1
# 889         Johnston, Miss. Catherine Helen "Carrie"                   0
# 890         Behr, Mr. Karl Howell                                      1
# 891         Dooley, Mr. Patrick                                        0
#
#                                                                 Pclass  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                  3
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# 3           Heikkinen, Miss. Laina                                   3
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# 5           Allen, Mr. William Henry                                 3
# ...                                                                ...
# 887         Montvila, Rev. Juozas                                    2
# 888         Graham, Miss. Margaret Edith                             1
# 889         Johnston, Miss. Catherine Helen "Carrie"                 3
# 890         Behr, Mr. Karl Howell                                    1
# 891         Dooley, Mr. Patrick                                      3
#
#                                                                    Sex   Age  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                               male  22.0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0
# 3           Heikkinen, Miss. Laina                              female  26.0
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0
# 5           Allen, Mr. William Henry                              male  35.0
# ...                                                                ...   ...
# 887         Montvila, Rev. Juozas                                 male  27.0
# 888         Graham, Miss. Margaret Edith                        female  19.0
# 889         Johnston, Miss. Catherine Helen "Carrie"            female   NaN
# 890         Behr, Mr. Karl Howell                                 male  26.0
# 891         Dooley, Mr. Patrick                                   male  32.0
#
#                                                                 SibSp  Parch  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                 1      0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# 3           Heikkinen, Miss. Laina                                  0      0
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# 5           Allen, Mr. William Henry                                0      0
# ...                                                               ...    ...
# 887         Montvila, Rev. Juozas                                   0      0
# 888         Graham, Miss. Margaret Edith                            0      0
# 889         Johnston, Miss. Catherine Helen "Carrie"                1      2
# 890         Behr, Mr. Karl Howell                                   0      0
# 891         Dooley, Mr. Patrick                                     0      0
#
#                                                                           Ticket  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                    A/5 21171
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599
# 3           Heikkinen, Miss. Laina                              STON/O2. 3101282
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803
# 5           Allen, Mr. William Henry                                      373450
# ...                                                                          ...
# 887         Montvila, Rev. Juozas                                         211536
# 888         Graham, Miss. Margaret Edith                                  112053
# 889         Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607
# 890         Behr, Mr. Karl Howell                                         111369
# 891         Dooley, Mr. Patrick                                           370376
#
#                                                                    Fare Cabin  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                              7.2500   NaN
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# 3           Heikkinen, Miss. Laina                               7.9250   NaN
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# 5           Allen, Mr. William Henry                             8.0500   NaN
# ...                                                                 ...   ...
# 887         Montvila, Rev. Juozas                               13.0000   NaN
# 888         Graham, Miss. Margaret Edith                        30.0000   B42
# 889         Johnston, Miss. Catherine Helen "Carrie"            23.4500   NaN
# 890         Behr, Mr. Karl Howell                               30.0000  C148
# 891         Dooley, Mr. Patrick                                  7.7500   NaN
#
#                                                                Embarked
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                   S
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...        C
# 3           Heikkinen, Miss. Laina                                    S
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)              S
# 5           Allen, Mr. William Henry                                  S
# ...                                                                 ...
# 887         Montvila, Rev. Juozas                                     S
# 888         Graham, Miss. Margaret Edith                              S
# 889         Johnston, Miss. Catherine Helen "Carrie"                  S
# 890         Behr, Mr. Karl Howell                                     C
# 891         Dooley, Mr. Patrick                                       Q
#
# [891 rows x 10 columns]

# %%
df.loc[(889, 'Johnston, Miss. Catherine Helen "Carrie"') : (891, 'Dooley, Mr. Patrick') , ["Pclass", "Age"]]
# Out:
#                                                       Pclass   Age
# PassengerId Name
# 889         Johnston, Miss. Catherine Helen "Carrie"       3   NaN
# 890         Behr, Mr. Karl Howell                          1  26.0
# 891         Dooley, Mr. Patrick                            3  32.0

# %%
df = df.set_index(["PassengerId", "Name"])
df

# %%
df.iloc[888:, [1,3]]
# Out:
#                                                       Pclass   Age
# PassengerId Name
# 889         Johnston, Miss. Catherine Helen "Carrie"       3   NaN
# 890         Behr, Mr. Karl Howell                          1  26.0
# 891         Dooley, Mr. Patrick                            3  32.0

# %% [markdown]
# * 인덱스를 숫자로 초기화
# * reset_index(drop=True)

# %%
df
# Out:
#                                                                 Survived  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                    0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...         1
# 3           Heikkinen, Miss. Laina                                     1
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)               1
# 5           Allen, Mr. William Henry                                   0
# ...                                                                  ...
# 887         Montvila, Rev. Juozas                                      0
# 888         Graham, Miss. Margaret Edith                               1
# 889         Johnston, Miss. Catherine Helen "Carrie"                   0
# 890         Behr, Mr. Karl Howell                                      1
# 891         Dooley, Mr. Patrick                                        0
#
#                                                                 Pclass  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                  3
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# 3           Heikkinen, Miss. Laina                                   3
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# 5           Allen, Mr. William Henry                                 3
# ...                                                                ...
# 887         Montvila, Rev. Juozas                                    2
# 888         Graham, Miss. Margaret Edith                             1
# 889         Johnston, Miss. Catherine Helen "Carrie"                 3
# 890         Behr, Mr. Karl Howell                                    1
# 891         Dooley, Mr. Patrick                                      3
#
#                                                                    Sex   Age  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                               male  22.0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0
# 3           Heikkinen, Miss. Laina                              female  26.0
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0
# 5           Allen, Mr. William Henry                            female  35.0
# ...                                                                ...   ...
# 887         Montvila, Rev. Juozas                                 male  27.0
# 888         Graham, Miss. Margaret Edith                        female  19.0
# 889         Johnston, Miss. Catherine Helen "Carrie"            female   NaN
# 890         Behr, Mr. Karl Howell                                 male  26.0
# 891         Dooley, Mr. Patrick                                   male  32.0
#
#                                                                 SibSp  Parch  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                 1      0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# 3           Heikkinen, Miss. Laina                                  0      0
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# 5           Allen, Mr. William Henry                                0      0
# ...                                                               ...    ...
# 887         Montvila, Rev. Juozas                                   0      0
# 888         Graham, Miss. Margaret Edith                            0      0
# 889         Johnston, Miss. Catherine Helen "Carrie"                1      2
# 890         Behr, Mr. Karl Howell                                   0      0
# 891         Dooley, Mr. Patrick                                     0      0
#
#                                                                           Ticket  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                    A/5 21171
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599
# 3           Heikkinen, Miss. Laina                              STON/O2. 3101282
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803
# 5           Allen, Mr. William Henry                                      373450
# ...                                                                          ...
# 887         Montvila, Rev. Juozas                                         211536
# 888         Graham, Miss. Margaret Edith                                  112053
# 889         Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607
# 890         Behr, Mr. Karl Howell                                         111369
# 891         Dooley, Mr. Patrick                                           370376
#
#                                                                    Fare Cabin  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                              7.2500   NaN
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# 3           Heikkinen, Miss. Laina                               7.9250   NaN
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# 5           Allen, Mr. William Henry                             8.0500   NaN
# ...                                                                 ...   ...
# 887         Montvila, Rev. Juozas                               13.0000   NaN
# 888         Graham, Miss. Margaret Edith                        30.0000   B42
# 889         Johnston, Miss. Catherine Helen "Carrie"            23.4500   NaN
# 890         Behr, Mr. Karl Howell                               30.0000  C148
# 891         Dooley, Mr. Patrick                                  7.7500   NaN
#
#                                                                Embarked
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                   S
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...        C
# 3           Heikkinen, Miss. Laina                                    S
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)              S
# 5           Allen, Mr. William Henry                                  S
# ...                                                                 ...
# 887         Montvila, Rev. Juozas                                     S
# 888         Graham, Miss. Margaret Edith                              S
# 889         Johnston, Miss. Catherine Helen "Carrie"                  S
# 890         Behr, Mr. Karl Howell                                     C
# 891         Dooley, Mr. Patrick                                       Q
#
# [891 rows x 10 columns]

# %%
# df.reset_index(drop=True)
df=df.reset_index()
df
# Out:
#      PassengerId                                               Name  Survived  \
# 0              1                            Braund, Mr. Owen Harris         0
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2              3                             Heikkinen, Miss. Laina         1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4              5                           Allen, Mr. William Henry         0
# ..           ...                                                ...       ...
# 886          887                              Montvila, Rev. Juozas         0
# 887          888                       Graham, Miss. Margaret Edith         1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"         0
# 889          890                              Behr, Mr. Karl Howell         1
# 890          891                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1  female  35.0      1      0            113803  53.1000  C123
# 4         3    male  35.0      0      0            373450   8.0500   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 886       2    male  27.0      0      0            211536  13.0000   NaN
# 887       1  female  19.0      0      0            112053  30.0000   B42
# 888       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 889       1    male  26.0      0      0            111369  30.0000  C148
# 890       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# * 컬럼이름 출력하기, 바꾸기
# * df.columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Name', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# * 컬럼이름 변경하기
# * rename(columns={'원래이름':'새이름', '원래이름2':'새이름2'}):

# %%
df.rename(columns={'PassengerId':'Pid', 'Survived':'surv'}, inplace=True) 
df
# Out:
#      Pid                                               Name  surv  Pclass  \
# 0      1                            Braund, Mr. Owen Harris     0       3
# 1      2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1       1
# 2      3                             Heikkinen, Miss. Laina     1       3
# 3      4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1       1
# 4      5                           Allen, Mr. William Henry     0       3
# ..   ...                                                ...   ...     ...
# 886  887                              Montvila, Rev. Juozas     0       2
# 887  888                       Graham, Miss. Margaret Edith     1       1
# 888  889           Johnston, Miss. Catherine Helen "Carrie"     0       3
# 889  890                              Behr, Mr. Karl Howell     1       1
# 890  891                                Dooley, Mr. Patrick     0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4    female  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.rename(index={0:'영번', 1:'일번'}, inplace=True) 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 영번             1         0       3
# 일번             2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 영번                             Braund, Mr. Owen Harris    male  22.0      1
# 일번   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 영번       0         A/5 21171   7.2500   NaN        S
# 일번       0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 영번             1         0       3
# 일번             2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 영번                             Braund, Mr. Owen Harris    male  22.0      1
# 일번   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  가족수
# 영번       0         A/5 21171   7.2500   NaN        S    0
# 일번       0          PC 17599  71.2833   C85        C    0
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0
# 3        0            113803  53.1000  C123        S    0
# 4        0            373450   8.0500   NaN        S    0
# ..     ...               ...      ...   ...      ...  ...
# 886      0            211536  13.0000   NaN        S    0
# 887      0            112053  30.0000   B42        S    0
# 888      2        W./C. 6607  23.4500   NaN        S    0
# 889      0            111369  30.0000  C148        C    0
# 890      0            370376   7.7500   NaN        Q    0
#
# [891 rows x 13 columns]

# %% [markdown]
# df.columns로 출력되는 리스트 길이와 같은 새로운 이름의 리스트로 덮어쓰기

# %%
df.columns
# Out:
# Index(['PassengerId', 'Name', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
newName = ['승객번호', '이름', '생존여부', '선실등급', '성별', '나이',
           '형제자매수', '부모자식수', '티켓번호', '티켓가격', 
           '선실번호', '목적지']

# %%
df.columns = newName
df
# Out:
#      승객번호                                                 이름  생존여부  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     0     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2       3                             Heikkinen, Miss. Laina     1     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4       5                           Allen, Mr. William Henry     0     3
# ..    ...                                                ...   ...   ...
# 886   887                              Montvila, Rev. Juozas     0     2
# 887   888                       Graham, Miss. Margaret Edith     1     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   890                              Behr, Mr. Karl Howell     1     1
# 890   891                                Dooley, Mr. Patrick     0     3
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN   S
# 1    female  38.0      1      0          PC 17599  71.2833   C85   C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN   S
# 3    female  35.0      1      0            113803  53.1000  C123   S
# 4      male  35.0      0      0            373450   8.0500   NaN   S
# ..      ...   ...    ...    ...               ...      ...   ...  ..
# 886    male  27.0      0      0            211536  13.0000   NaN   S
# 887  female  19.0      0      0            112053  30.0000   B42   S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN   S
# 889    male  26.0      0      0            111369  30.0000  C148   C
# 890    male  32.0      0      0            370376   7.7500   NaN   Q
#
# [891 rows x 12 columns]

# %% [markdown]
# * 컬럼 추가하기

# %% [markdown]
# * 컬럼 추가하기
# * 변수명['컬럼명'] = value

# %%
# 새로운 컬럼이 생성되면, 모든 행에 지시한 값이 삽입된다.
df['가족수'] = 0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 영번             1         0       3
# 일번             2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 영번                             Braund, Mr. Owen Harris    male  22.0      1
# 일번   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  가족수
# 영번       0         A/5 21171   7.2500   NaN        S    0
# 일번       0          PC 17599  71.2833   C85        C    0
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0
# 3        0            113803  53.1000  C123        S    0
# 4        0            373450   8.0500   NaN        S    0
# ..     ...               ...      ...   ...      ...  ...
# 886      0            211536  13.0000   NaN        S    0
# 887      0            112053  30.0000   B42        S    0
# 888      2        W./C. 6607  23.4500   NaN        S    0
# 889      0            111369  30.0000  C148        C    0
# 890      0            370376   7.7500   NaN        Q    0
#
# [891 rows x 13 columns]

# %%
# 요소들이 정수이기에 가능하다.
df['가족수'] = df['형제자매수'] + df['부모자식수']
df

# %% [markdown]
# * 컬럼 삭제하기
# * del df['컬럼명']
# * df.drop('컬럼명', axis=1, inplace=True)

# %%
del df['형제자매수']
df
# Out:
#      승객번호                                                 이름  생존여부  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     0     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2       3                             Heikkinen, Miss. Laina     1     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4       5                           Allen, Mr. William Henry     0     3
# ..    ...                                                ...   ...   ...
# 886   887                              Montvila, Rev. Juozas     0     2
# 887   888                       Graham, Miss. Margaret Edith     1     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   890                              Behr, Mr. Karl Howell     1     1
# 890   891                                Dooley, Mr. Patrick     0     3
#
#          성별    나이  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# 0      male  22.0      0         A/5 21171   7.2500   NaN   S    1
# 1    female  38.0      0          PC 17599  71.2833   C85   C    1
# 2    female  26.0      0  STON/O2. 3101282   7.9250   NaN   S    0
# 3    female  35.0      0            113803  53.1000  C123   S    1
# 4    female  35.0      0            373450   8.0500   NaN   S    0
# ..      ...   ...    ...               ...      ...   ...  ..  ...
# 886    male  27.0      0            211536  13.0000   NaN   S    0
# 887  female  19.0      0            112053  30.0000   B42   S    0
# 888  female   NaN      2        W./C. 6607  23.4500   NaN   S    3
# 889    male  26.0      0            111369  30.0000  C148   C    0
# 890    male  32.0      0            370376   7.7500   NaN   Q    0
#
# [891 rows x 12 columns]

# %%
df = df.drop('부모자식수', axis=1)
df
# Out:
#      승객번호                                                 이름  생존여부  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     0     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2       3                             Heikkinen, Miss. Laina     1     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4       5                           Allen, Mr. William Henry     0     3
# ..    ...                                                ...   ...   ...
# 886   887                              Montvila, Rev. Juozas     0     2
# 887   888                       Graham, Miss. Margaret Edith     1     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   890                              Behr, Mr. Karl Howell     1     1
# 890   891                                Dooley, Mr. Patrick     0     3
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지  가족수
# 0      male  22.0         A/5 21171   7.2500   NaN   S    1
# 1    female  38.0          PC 17599  71.2833   C85   C    1
# 2    female  26.0  STON/O2. 3101282   7.9250   NaN   S    0
# 3    female  35.0            113803  53.1000  C123   S    1
# 4    female  35.0            373450   8.0500   NaN   S    0
# ..      ...   ...               ...      ...   ...  ..  ...
# 886    male  27.0            211536  13.0000   NaN   S    0
# 887  female  19.0            112053  30.0000   B42   S    0
# 888  female   NaN        W./C. 6607  23.4500   NaN   S    3
# 889    male  26.0            111369  30.0000  C148   C    0
# 890    male  32.0            370376   7.7500   NaN   Q    0
#
# [891 rows x 11 columns]

# %%
df.pop("부모자식수")
df

# %%
df.columns
# Out:
# Index(['승객번호', '이름', '생존여부', '선실등급', '성별', '나이', '티켓번호', '티켓가격', '선실번호', '목적지',
#        '가족수'],
#       dtype='object')

# %%
drop_cols = ['승객번호', '이름', '티켓번호', '티켓가격', '선실번호', '목적지',
       '가족수']

# %%
df.drop(drop_cols, axis=1)
# Out:
#      생존여부  선실등급      성별    나이
# 0       0     3    male  22.0
# 1       1     1  female  38.0
# 2       1     3  female  26.0
# 3       1     1  female  35.0
# 4       0     3  female  35.0
# ..    ...   ...     ...   ...
# 886     0     2    male  27.0
# 887     1     1  female  19.0
# 888     0     3  female   NaN
# 889     1     1    male  26.0
# 890     0     3    male  32.0
#
# [891 rows x 4 columns]

# %% [markdown]
# * 데이터 타입 바꾸기
# * astype(자료형)
# * apply(형변환함수)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    int64
#  1   이름      891 non-null    object
#  2   생존여부    891 non-null    int64
#  3   선실등급    891 non-null    int64
#  4   성별      891 non-null    object
#  5   나이      715 non-null    float64
#  6   티켓번호    891 non-null    object
#  7   티켓가격    891 non-null    float64
#  8   선실번호    204 non-null    object
#  9   목적지     889 non-null    object
#  10  가족수     891 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df['승객번호'].dtype
# Out:
# dtype('int64')

# %%
df['승객번호'].astype('str')
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: 승객번호, Length: 891, dtype: object

# %%
df['승객번호'] = df['승객번호'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    float64
#  1   이름      891 non-null    object
#  2   생존여부    891 non-null    int64
#  3   선실등급    891 non-null    int64
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   부모자식수   891 non-null    int64
#  7   티켓번호    891 non-null    object
#  8   티켓가격    891 non-null    float64
#  9   선실번호    204 non-null    object
#  10  목적지     889 non-null    object
#  11  가족수     891 non-null    int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %%
df['승객번호'] = df['승객번호'].apply(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    object
#  1   이름      891 non-null    object
#  2   생존여부    891 non-null    int64
#  3   선실등급    891 non-null    int64
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   부모자식수   891 non-null    int64
#  7   티켓번호    891 non-null    object
#  8   티켓가격    891 non-null    float64
#  9   선실번호    204 non-null    object
#  10  목적지     889 non-null    object
#  11  가족수     891 non-null    int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df['승객번호'] = df['승객번호'].apply(lambda x: "짝수" if float(x) % 2 == 0 else "홀수")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    object
#  1   이름      891 non-null    object
#  2   생존여부    891 non-null    int64
#  3   선실등급    891 non-null    int64
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   부모자식수   891 non-null    int64
#  7   티켓번호    891 non-null    object
#  8   티켓가격    891 non-null    float64
#  9   선실번호    204 non-null    object
#  10  목적지     889 non-null    object
#  11  가족수     891 non-null    int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 0     홀수                            Braund, Mr. Owen Harris     0     3
# 1     짝수  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2     홀수                             Heikkinen, Miss. Laina     1     3
# 3     짝수       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4     홀수                           Allen, Mr. William Henry     0     3
# ..   ...                                                ...   ...   ...
# 886   홀수                              Montvila, Rev. Juozas     0     2
# 887   짝수                       Graham, Miss. Margaret Edith     1     1
# 888   홀수           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   짝수                              Behr, Mr. Karl Howell     1     1
# 890   홀수                                Dooley, Mr. Patrick     0     3
#
#          성별    나이  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# 0      male  22.0      0         A/5 21171   7.2500   NaN   S    1
# 1    female  38.0      0          PC 17599  71.2833   C85   C    1
# 2    female  26.0      0  STON/O2. 3101282   7.9250   NaN   S    0
# 3    female  35.0      0            113803  53.1000  C123   S    1
# 4      male  35.0      0            373450   8.0500   NaN   S    0
# ..      ...   ...    ...               ...      ...   ...  ..  ...
# 886    male  27.0      0            211536  13.0000   NaN   S    0
# 887  female  19.0      0            112053  30.0000   B42   S    0
# 888  female   NaN      2        W./C. 6607  23.4500   NaN   S    3
# 889    male  26.0      0            111369  30.0000  C148   C    0
# 890    male  32.0      0            370376   7.7500   NaN   Q    0
#
# [891 rows x 12 columns]

# %% [markdown]
# # 판다스 데이터프레임에서 조건에 맞는 행만 가져오기
# * df[df['컬럼명'] 조건식]
# * 조건식 연산자 <, <=, >, >=, ==, !=, &(and), |(or)

# %%
df['승객번호'] == "홀수"
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: 승객번호, Length: 891, dtype: bool

# %%
df[df['승객번호'] == "홀수"]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 0     홀수                            Braund, Mr. Owen Harris     0     3
# 2     홀수                             Heikkinen, Miss. Laina     1     3
# 4     홀수                           Allen, Mr. William Henry     0     3
# 6     홀수                            McCarthy, Mr. Timothy J     0     1
# 8     홀수  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     1     3
# ..   ...                                                ...   ...   ...
# 882   홀수                       Dahlberg, Miss. Gerda Ulrika     0     3
# 884   홀수                             Sutehall, Mr. Henry Jr     0     3
# 886   홀수                              Montvila, Rev. Juozas     0     2
# 888   홀수           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 890   홀수                                Dooley, Mr. Patrick     0     3
#
#          성별    나이  부모자식수              티켓번호     티켓가격 선실번호 목적지  가족수
# 0      male  22.0      0         A/5 21171   7.2500  NaN   S    1
# 2    female  26.0      0  STON/O2. 3101282   7.9250  NaN   S    0
# 4      male  35.0      0            373450   8.0500  NaN   S    0
# 6      male  54.0      0             17463  51.8625  E46   S    0
# 8    female  27.0      2            347742  11.1333  NaN   S    2
# ..      ...   ...    ...               ...      ...  ...  ..  ...
# 882  female  22.0      0              7552  10.5167  NaN   S    0
# 884    male  25.0      0   SOTON/OQ 392076   7.0500  NaN   S    0
# 886    male  27.0      0            211536  13.0000  NaN   S    0
# 888  female   NaN      2        W./C. 6607  23.4500  NaN   S    3
# 890    male  32.0      0            370376   7.7500  NaN   Q    0
#
# [446 rows x 12 columns]

# %%
# 나이가 35 초과인 사람만 필터링
df[df['나이'] > 35]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 1     짝수  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 6     홀수                            McCarthy, Mr. Timothy J     0     1
# 11    짝수                           Bonnell, Miss. Elizabeth     1     1
# 13    짝수                        Andersson, Mr. Anders Johan     0     3
# 15    짝수                   Hewlett, Mrs. (Mary D Kingcome)      1     2
# ..   ...                                                ...   ...   ...
# 865   짝수                           Bystrom, Mrs. (Karolina)     1     2
# 871   짝수   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1     1
# 873   짝수                        Vander Cruyssen, Mr. Victor     0     3
# 879   짝수      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1     1
# 885   짝수               Rice, Mrs. William (Margaret Norton)     0     3
#
#          성별    나이  부모자식수      티켓번호     티켓가격  선실번호 목적지  가족수
# 1    female  38.0      0  PC 17599  71.2833   C85   C    1
# 6      male  54.0      0     17463  51.8625   E46   S    0
# 11   female  58.0      0    113783  26.5500  C103   S    0
# 13     male  39.0      5    347082  31.2750   NaN   S    6
# 15   female  55.0      0    248706  16.0000   NaN   S    0
# ..      ...   ...    ...       ...      ...   ...  ..  ...
# 865  female  42.0      0    236852  13.0000   NaN   S    0
# 871  female  47.0      1     11751  52.5542   D35   S    2
# 873    male  47.0      0    345765   9.0000   NaN   S    0
# 879  female  56.0      1     11767  83.1583   C50   C    1
# 885  female  39.0      5    382652  29.1250   NaN   Q    5
#
# [217 rows x 12 columns]

# %% [markdown]
# * 여성이면서 나이가 35세 초과인 행 찾기 and 조건

# %%
df[(df['성별'] == 'female') & (df['나이'] > 35)]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 1     짝수  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 11    짝수                           Bonnell, Miss. Elizabeth     1     1
# 15    짝수                   Hewlett, Mrs. (Mary D Kingcome)      1     2
# 25    짝수  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...     1     3
# 40    홀수     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)     0     3
# ..   ...                                                ...   ...   ...
# 862   홀수  Swift, Mrs. Frederick Joel (Margaret Welles Ba...     1     1
# 865   짝수                           Bystrom, Mrs. (Karolina)     1     2
# 871   짝수   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1     1
# 879   짝수      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1     1
# 885   짝수               Rice, Mrs. William (Margaret Norton)     0     3
#
#          성별    나이  부모자식수      티켓번호     티켓가격  선실번호 목적지  가족수
# 1    female  38.0      0  PC 17599  71.2833   C85   C    1
# 11   female  58.0      0    113783  26.5500  C103   S    0
# 15   female  55.0      0    248706  16.0000   NaN   S    0
# 25   female  38.0      5    347077  31.3875   NaN   S    6
# 40   female  40.0      0      7546   9.4750   NaN   S    1
# ..      ...   ...    ...       ...      ...   ...  ..  ...
# 862  female  48.0      0     17466  25.9292   D17   S    0
# 865  female  42.0      0    236852  13.0000   NaN   S    0
# 871  female  47.0      1     11751  52.5542   D35   S    2
# 879  female  56.0      1     11767  83.1583   C50   C    1
# 885  female  39.0      5    382652  29.1250   NaN   Q    5
#
# [73 rows x 12 columns]

# %% [markdown]
# * 성별이 male, 선실등급  1, 생존여부 1인 사람을 찾으세요.

# %%
df[(df['성별'] == 'male') & (df['선실등급'] == 1) & (df['생존여부'] == 1)]
# Out:
#     승객번호                                             이름  생존여부  선실등급    성별  \
# 23    짝수                   Sloper, Mr. William Thompson     1     1  male
# 55    짝수                              Woolner, Mr. Hugh     1     1  male
# 97    짝수                Greenfield, Mr. William Bertram     1     1  male
# 187   짝수  Romaine, Mr. Charles Hallace ("Mr C Rolmane")     1     1  male
# 209   짝수                               Blank, Mr. Henry     1     1  male
# 224   홀수                   Hoyt, Mr. Frederick Maxfield     1     1  male
# 248   홀수                  Beckwith, Mr. Richard Leonard     1     1  male
# 298   홀수                          Saalfeld, Mr. Adolphe     1     1  male
# 305   짝수                 Allison, Master. Hudson Trevor     1     1  male
# 370   홀수                    Harder, Mr. George Achilles     1     1  male
# 390   홀수                     Carter, Mr. William Ernest     1     1  male
# 430   홀수      Bjornstrom-Steffansson, Mr. Mauritz Hakan     1     1  male
# 445   짝수                      Dodge, Master. Washington     1     1  male
# 447   짝수                    Seward, Mr. Frederic Kimber     1     1  male
# 449   짝수                 Peuchen, Major. Arthur Godfrey     1     1  male
# 453   짝수                       Goldenberg, Mr. Samuel L     1     1  male
# 460   홀수                            Anderson, Mr. Harry     1     1  male
# 484   홀수                        Bishop, Mr. Dickinson H     1     1  male
# 507   짝수  Bradley, Mr. George ("George Arthur Brayton")     1     1  male
# 512   홀수                      McGough, Mr. James Robert     1     1  male
# 550   홀수                    Thayer, Mr. John Borland Jr     1     1  male
# 572   홀수               Flynn, Mr. John Irwin ("Irving")     1     1  male
# 587   짝수               Frolicher-Stehli, Mr. Maxmillian     1     1  male
# 599   짝수   Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")     1     1  male
# 604   홀수                Homer, Mr. Harry ("Mr E Haven")     1     1  male
# 607   짝수                    Daniel, Mr. Robert Williams     1     1  male
# 621   짝수                   Kimball, Mr. Edwin Nelson Jr     1     1  male
# 630   홀수           Barkworth, Mr. Algernon Henry Wilson     1     1  male
# 632   홀수                      Stahelin-Maeglin, Dr. Max     1     1  male
# 645   짝수                      Harper, Mr. Henry Sleeper     1     1  male
# 647   짝수            Simonius-Blumer, Col. Oberst Alfons     1     1  male
# 660   홀수                  Frauenthal, Dr. Henry William     1     1  male
# 679   짝수             Cardeza, Mr. Thomas Drake Martinez     1     1  male
# 681   짝수                             Hassab, Mr. Hammad     1     1  male
# 690   홀수                        Dick, Mr. Albert Adrian     1     1  male
# 701   짝수               Silverthorne, Mr. Spencer Victor     1     1  male
# 707   짝수              Calderhead, Mr. Edward Pennington     1     1  male
# 712   홀수                       Taylor, Mr. Elmer Zebley     1     1  male
# 724   홀수                  Chambers, Mr. Norman Campbell     1     1  male
# 737   짝수                         Lesurer, Mr. Gustave J     1     1  male
# 740   홀수                    Hawksford, Mr. Walter James     1     1  male
# 802   홀수            Carter, Master. William Thornton II     1     1  male
# 839   짝수                           Marechal, Mr. Pierre     1     1  male
# 857   짝수                         Daly, Mr. Peter Denis      1     1  male
# 889   짝수                          Behr, Mr. Karl Howell     1     1  male
#
#         나이  부모자식수      티켓번호      티켓가격         선실번호 목적지  가족수
# 23   28.00      0    113788   35.5000           A6   S    0
# 55     NaN      0     19947   35.5000          C52   S    0
# 97   23.00      1  PC 17759   63.3583      D10 D12   C    1
# 187  45.00      0    111428   26.5500          NaN   S    0
# 209  40.00      0    112277   31.0000          A31   C    0
# 224  38.00      0     19943   90.0000          C93   S    1
# 248  37.00      1     11751   52.5542          D35   S    2
# 298    NaN      0     19988   30.5000         C106   S    0
# 305   0.92      2    113781  151.5500      C22 C26   S    3
# 370  25.00      0     11765   55.4417          E50   C    1
# 390  36.00      2    113760  120.0000      B96 B98   S    3
# 430  28.00      0    110564   26.5500          C52   S    0
# 445   4.00      2     33638   81.8583          A34   S    2
# 447  34.00      0    113794   26.5500          NaN   S    0
# 449  52.00      0    113786   30.5000         C104   S    0
# 453  49.00      0     17453   89.1042          C92   C    1
# 460  48.00      0     19952   26.5500          E12   S    0
# 484  25.00      0     11967   91.0792          B49   C    1
# 507    NaN      0    111427   26.5500          NaN   S    0
# 512  36.00      0  PC 17473   26.2875          E25   S    0
# 550  17.00      2     17421  110.8833          C70   C    2
# 572  36.00      0  PC 17474   26.3875          E25   S    0
# 587  60.00      1     13567   79.2000          B41   C    2
# 599  49.00      0  PC 17485   56.9292          A20   C    1
# 604  35.00      0    111426   26.5500          NaN   C    0
# 607  27.00      0    113804   30.5000          NaN   S    0
# 621  42.00      0     11753   52.5542          D19   S    1
# 630  80.00      0     27042   30.0000          A23   S    0
# 632  32.00      0     13214   30.5000          B50   C    0
# 645  48.00      0  PC 17572   76.7292          D33   C    1
# 647  56.00      0     13213   35.5000          A26   C    0
# 660  50.00      0  PC 17611  133.6500          NaN   S    2
# 679  36.00      1  PC 17755  512.3292  B51 B53 B55   C    1
# 681  27.00      0  PC 17572   76.7292          D49   C    0
# 690  31.00      0     17474   57.0000          B20   S    1
# 701  35.00      0  PC 17475   26.2875          E24   S    0
# 707  42.00      0  PC 17476   26.2875          E24   S    0
# 712  48.00      0     19996   52.0000         C126   S    1
# 724  27.00      0    113806   53.1000           E8   S    1
# 737  35.00      0  PC 17755  512.3292         B101   C    0
# 740    NaN      0     16988   30.0000          D45   S    0
# 802  11.00      2    113760  120.0000      B96 B98   S    3
# 839    NaN      0     11774   29.7000          C47   C    0
# 857  51.00      0    113055   26.5500          E17   S    0
# 889  26.00      0    111369   30.0000         C148   C    0

# %%
len(df[(df['성별'] == 'male') & (df['선실등급'] == 1) & (df['생존여부'] == 1)])
# Out:
# 45

# %% [markdown]
# * 선실 등급별 승차권 금액의 최소, 최대, 평균 등 4분위수를 보고 싶다.

# %%
# 선실 등급이 1등석인 사람들의 승차권 금액 통계량을 보고 싶다.
# df[df['선실등급'] == 1]['티켓가격'].describe()
df[df['선실등급'] == 1]['티켓가격'].describe()
# Out:
# count    216.000000
# mean      84.154687
# std       78.380373
# min        0.000000
# 25%       30.923950
# 50%       60.287500
# 75%       93.500000
# max      512.329200
# Name: 티켓가격, dtype: float64

# %%
df[df['티켓가격'] > 512]
# Out:
#      승객번호                                  이름  생존여부  선실등급      성별    나이  \
# 258   259                    Ward, Miss. Anna     1     1  female  35.0
# 679   680  Cardeza, Mr. Thomas Drake Martinez     1     1    male  36.0
# 737   738              Lesurer, Mr. Gustave J     1     1    male  35.0
#
#      형제자매수  부모자식수      티켓번호      티켓가격         선실번호 목적지
# 258      0      0  PC 17755  512.3292          NaN   C
# 679      0      1  PC 17755  512.3292  B51 B53 B55   C
# 737      0      0  PC 17755  512.3292         B101   C

# %%
df[df['선실등급'] == 2]['티켓가격'].describe()
# Out:
# count    184.000000
# mean      20.662183
# std       13.417399
# min        0.000000
# 25%       13.000000
# 50%       14.250000
# 75%       26.000000
# max       73.500000
# Name: 티켓가격, dtype: float64

# %%
df[df['티켓가격']==0]
# Out:
#     승객번호                                이름  생존여부  선실등급    성별    나이  부모자식수  \
# 179   짝수               Leonard, Mr. Lionel     0     3  male  36.0      0
# 263   짝수             Harrison, Mr. William     0     1  male  40.0      0
# 271   짝수      Tornquist, Mr. William Henry     1     3  male  25.0      0
# 277   짝수       Parkes, Mr. Francis "Frank"     0     2  male   NaN      0
# 302   홀수   Johnson, Mr. William Cahoone Jr     0     3  male  19.0      0
# 413   짝수    Cunningham, Mr. Alfred Fleming     0     2  male   NaN      0
# 466   홀수             Campbell, Mr. William     0     2  male   NaN      0
# 481   짝수  Frost, Mr. Anthony Wood "Archie"     0     2  male   NaN      0
# 597   짝수               Johnson, Mr. Alfred     0     3  male  49.0      0
# 633   짝수     Parr, Mr. William Henry Marsh     0     1  male   NaN      0
# 674   홀수        Watson, Mr. Ennis Hastings     0     2  male   NaN      0
# 732   홀수              Knight, Mr. Robert J     0     2  male   NaN      0
# 806   홀수            Andrews, Mr. Thomas Jr     0     1  male  39.0      0
# 815   짝수                  Fry, Mr. Richard     0     1  male   NaN      0
# 822   홀수   Reuchlin, Jonkheer. John George     0     1  male  38.0      0
#
#        티켓번호  티켓가격  선실번호 목적지  가족수
# 179    LINE   0.0   NaN   S    0
# 263  112059   0.0   B94   S    0
# 271    LINE   0.0   NaN   S    0
# 277  239853   0.0   NaN   S    0
# 302    LINE   0.0   NaN   S    0
# 413  239853   0.0   NaN   S    0
# 466  239853   0.0   NaN   S    0
# 481  239854   0.0   NaN   S    0
# 597    LINE   0.0   NaN   S    0
# 633  112052   0.0   NaN   S    0
# 674  239856   0.0   NaN   S    0
# 732  239855   0.0   NaN   S    0
# 806  112050   0.0   A36   S    0
# 815  112058   0.0  B102   S    0
# 822   19972   0.0   NaN   S    0

# %% [markdown]
# # 조건에 맞는 행을 찾은 후 특정 컬럼만 조회하기

# %% [markdown]
# * 선실등급이 1이거나 2이면서 생존한 여성 중에서 이름 컬럼만 보고 싶을 때

# %%
df.loc[((df['선실등급'] == 1) | (df['선실등급'] == 2)) & (df['생존여부'] == 1) & (df['성별'] == 'female'), '이름']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 이름, Length: 161, dtype: object

# %%
df[((df['선실등급'] == 1) | (df['선실등급'] == 2)) & (df['생존여부'] == 1) & (df['성별'] == 'female')]['이름']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 이름, Length: 161, dtype: object

# %% [markdown]
# * 나이가 25세 미만이면서 생존자의 이름

# %%
# 결과에서 이름과 나이를 같이 보고 싶다.
df.loc[(df['나이'] < 25) & (df['생존여부'] == 1), ['이름', '나이']]
# Out:
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %%
df[(df['나이'] < 25) & (df['생존여부'] == 1)][['이름', '나이']]
# Out:
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %% [markdown]
# .isin([조건1, 조건2]) or 조건을 여러 번 써야 할 때 간단히 표현

# %% [markdown]
# 선실등급이 1, 2인 사람

# %%
df[df['선실등급'].isin([1,2])]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 1     짝수  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 3     짝수       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 6     홀수                            McCarthy, Mr. Timothy J     0     1
# 9     짝수                Nasser, Mrs. Nicholas (Adele Achem)     1     2
# 11    짝수                           Bonnell, Miss. Elizabeth     1     1
# ..   ...                                                ...   ...   ...
# 880   홀수       Shelley, Mrs. William (Imanita Parrish Hall)     1     2
# 883   짝수                      Banfield, Mr. Frederick James     0     2
# 886   홀수                              Montvila, Rev. Juozas     0     2
# 887   짝수                       Graham, Miss. Margaret Edith     1     1
# 889   짝수                              Behr, Mr. Karl Howell     1     1
#
#          성별    나이  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# 1    female  38.0      0          PC 17599  71.2833   C85   C    1
# 3    female  35.0      0            113803  53.1000  C123   S    1
# 6      male  54.0      0             17463  51.8625   E46   S    0
# 9    female  14.0      0            237736  30.0708   NaN   C    1
# 11   female  58.0      0            113783  26.5500  C103   S    0
# ..      ...   ...    ...               ...      ...   ...  ..  ...
# 880  female  25.0      1            230433  26.0000   NaN   S    1
# 883    male  28.0      0  C.A./SOTON 34068  10.5000   NaN   S    0
# 886    male  27.0      0            211536  13.0000   NaN   S    0
# 887  female  19.0      0            112053  30.0000   B42   S    0
# 889    male  26.0      0            111369  30.0000  C148   C    0
#
# [400 rows x 12 columns]

# %% [markdown]
# # 특정 단어를 포함한 행 찾기
# * 이름에 Joseph가 들어간 사람 찾기
# * like %단어% - SQL
# * .str.contains("찾을 단어")

# %%
df[df['이름'].str.contains("Joseph")]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 20    홀수                               Fynney, Mr. Joseph J     0     2
# 34    홀수                            Meyer, Mr. Edgar Joseph     0     1
# 95    짝수                        Shorney, Mr. Charles Joseph     0     3
# 140   홀수                      Boulos, Mrs. Joseph (Sultana)     0     3
# 145   짝수                       Nicholls, Mr. Joseph Charles     0     2
# 194   홀수          Brown, Mrs. James Joseph (Margaret Tobin)     1     1
# 375   짝수              Meyer, Mrs. Edgar Joseph (Leila Saks)     1     1
# 454   홀수                                Peduzzi, Mr. Joseph     0     3
# 532   홀수                               Elias, Mr. Joseph Jr     0     3
# 559   짝수       de Messemaeker, Mrs. Guillaume Joseph (Emma)     1     3
# 578   홀수                   Caram, Mrs. Joseph (Maria Elias)     0     3
# 589   짝수                                Murdlin, Mr. Joseph     0     3
# 608   홀수  Laroche, Mrs. Joseph (Juliette Marie Louise La...     1     2
# 685   짝수             Laroche, Mr. Joseph Philippe Lemercier     0     2
# 752   홀수                   Vande Velde, Mr. Johannes Joseph     0     3
# 828   홀수                       McCormack, Mr. Thomas Joseph     1     3
#
#          성별    나이  부모자식수           티켓번호     티켓가격 선실번호 목적지  가족수
# 20     male  35.0      0         239865  26.0000  NaN   S    0
# 34     male  28.0      0       PC 17604  82.1708  NaN   C    1
# 95     male   NaN      0         374910   8.0500  NaN   S    0
# 140  female   NaN      2           2678  15.2458  NaN   C    2
# 145    male  19.0      1     C.A. 33112  36.7500  NaN   S    2
# 194  female  44.0      0       PC 17610  27.7208   B4   C    0
# 375  female   NaN      0       PC 17604  82.1708  NaN   C    1
# 454    male   NaN      0       A/5 2817   8.0500  NaN   S    0
# 532    male  17.0      1           2690   7.2292  NaN   C    2
# 559  female  36.0      0         345572  17.4000  NaN   S    1
# 578  female   NaN      0           2689  14.4583  NaN   C    1
# 589    male   NaN      0     A./5. 3235   8.0500  NaN   S    0
# 608  female  22.0      2  SC/Paris 2123  41.5792  NaN   C    3
# 685    male  25.0      2  SC/Paris 2123  41.5792  NaN   C    3
# 752    male  33.0      0         345780   9.5000  NaN   S    0
# 828    male   NaN      0         367228   7.7500  NaN   Q    0

# %%
# 티켓번호에 PC라는 문자가 포함된 티켓을 필터링
df[df['티켓번호'].str.contains("PC")]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 1     짝수  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 30    홀수                           Uruchurtu, Don. Manuel E     0     1
# 31    짝수     Spencer, Mrs. William Augustus (Marie Eugenie)     1     1
# 34    홀수                            Meyer, Mr. Edgar Joseph     0     1
# 52    홀수           Harper, Mrs. Henry Sleeper (Myna Haxtun)     1     1
# 64    홀수                              Stewart, Mr. Albert A     0     1
# 96    홀수                          Goldschmidt, Mr. George B     0     1
# 97    짝수                    Greenfield, Mr. William Bertram     1     1
# 118   홀수                           Baxter, Mr. Quigg Edmond     0     1
# 139   짝수                                 Giglio, Mr. Victor     0     1
# 155   짝수                        Williams, Mr. Charles Duane     0     1
# 168   홀수                                Baumann, Mr. John D     0     1
# 177   짝수                         Isham, Miss. Ann Elizabeth     0     1
# 194   홀수          Brown, Mrs. James Joseph (Margaret Tobin)     1     1
# 195   짝수                               Lurette, Miss. Elise     1     1
# 256   홀수                     Thorne, Mrs. Gertrude Maybelle     1     1
# 258   홀수                                   Ward, Miss. Anna     1     1
# 268   홀수      Graham, Mrs. William Thompson (Edith Junkins)     1     1
# 269   짝수                             Bissette, Miss. Amelia     1     1
# 273   짝수                              Natsch, Mr. Charles H     0     1
# 295   짝수                                  Lewy, Mr. Ervin G     0     1
# 299   짝수    Baxter, Mrs. James (Helene DeLaudeniere Chaput)     1     1
# 307   짝수  Penasco y Castellana, Mrs. Victor de Satode (M...     1     1
# 309   짝수                     Francatelli, Miss. Laura Mabel     1     1
# 311   짝수                         Ryerson, Miss. Emily Borie     1     1
# 325   짝수                           Young, Miss. Marie Grice     1     1
# 332   홀수                          Graham, Mr. George Edward     0     1
# 334   홀수  Frauenthal, Mrs. Henry William (Clara Heinshei...     1     1
# 369   짝수                      Aubart, Mme. Leontine Pauline     1     1
# 373   짝수                                Ringhini, Mr. Sante     0     1
# 375   짝수              Meyer, Mrs. Edgar Joseph (Leila Saks)     1     1
# 380   홀수                              Bidois, Miss. Rosalie     1     1
# 493   짝수                            Artagaveytia, Mr. Ramon     0     1
# 505   짝수         Penasco y Castellana, Mr. Victor de Satode     0     1
# 512   홀수                          McGough, Mr. James Robert     1     1
# 513   짝수     Rothschild, Mrs. Martin (Elizabeth L. Barrett)     1     1
# 527   짝수                                 Farthing, Mr. John     0     1
# 537   짝수                                LeRoy, Miss. Bertha     1     1
# 544   홀수                         Douglas, Mr. Walter Donald     0     1
# 557   짝수                                Robbins, Mr. Victor     0     1
# 572   홀수                   Flynn, Mr. John Irwin ("Irving")     1     1
# 599   짝수       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")     1     1
# 609   짝수                          Shutes, Miss. Elizabeth W     1     1
# 641   짝수                               Sagesser, Mlle. Emma     1     1
# 645   짝수                          Harper, Mr. Henry Sleeper     1     1
# 660   홀수                      Frauenthal, Dr. Henry William     1     1
# 679   짝수                 Cardeza, Mr. Thomas Drake Martinez     1     1
# 681   짝수                                 Hassab, Mr. Hammad     1     1
# 700   홀수  Astor, Mrs. John Jacob (Madeleine Talmadge Force)     1     1
# 701   짝수                   Silverthorne, Mr. Spencer Victor     1     1
# 707   짝수                  Calderhead, Mr. Edward Pennington     1     1
# 710   홀수   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")     1     1
# 716   홀수                      Endres, Miss. Caroline Louise     1     1
# 737   짝수                             Lesurer, Mr. Gustave J     1     1
# 742   홀수              Ryerson, Miss. Susan Parker "Suzette"     1     1
# 789   짝수                           Guggenheim, Mr. Benjamin     0     1
# 793   짝수                           Hoyt, Mr. William Fisher     0     1
# 835   짝수                        Compton, Miss. Sara Rebecca     1     1
# 853   짝수                          Lines, Miss. Mary Conover     1     1
# 867   짝수               Roebling, Mr. Washington Augustus II     0     1
#
#          성별    나이  부모자식수      티켓번호      티켓가격             선실번호 목적지  가족수
# 1    female  38.0      0  PC 17599   71.2833              C85   C    1
# 30     male  40.0      0  PC 17601   27.7208              NaN   C    0
# 31   female   NaN      0  PC 17569  146.5208              B78   C    1
# 34     male  28.0      0  PC 17604   82.1708              NaN   C    1
# 52   female  49.0      0  PC 17572   76.7292              D33   C    1
# 64     male   NaN      0  PC 17605   27.7208              NaN   C    0
# 96     male  71.0      0  PC 17754   34.6542               A5   C    0
# 97     male  23.0      1  PC 17759   63.3583          D10 D12   C    1
# 118    male  24.0      1  PC 17558  247.5208          B58 B60   C    1
# 139    male  24.0      0  PC 17593   79.2000              B86   C    0
# 155    male  51.0      1  PC 17597   61.3792              NaN   C    1
# 168    male   NaN      0  PC 17318   25.9250              NaN   S    0
# 177  female  50.0      0  PC 17595   28.7125              C49   C    0
# 194  female  44.0      0  PC 17610   27.7208               B4   C    0
# 195  female  58.0      0  PC 17569  146.5208              B80   C    0
# 256  female   NaN      0  PC 17585   79.2000              NaN   C    0
# 258  female  35.0      0  PC 17755  512.3292              NaN   C    0
# 268  female  58.0      1  PC 17582  153.4625             C125   S    1
# 269  female  35.0      0  PC 17760  135.6333              C99   S    0
# 273    male  37.0      1  PC 17596   29.7000             C118   C    1
# 295    male   NaN      0  PC 17612   27.7208              NaN   C    0
# 299  female  50.0      1  PC 17558  247.5208          B58 B60   C    1
# 307  female  17.0      0  PC 17758  108.9000              C65   C    1
# 309  female  30.0      0  PC 17485   56.9292              E36   C    0
# 311  female  18.0      2  PC 17608  262.3750  B57 B59 B63 B66   C    4
# 325  female  36.0      0  PC 17760  135.6333              C32   C    0
# 332    male  38.0      1  PC 17582  153.4625              C91   S    1
# 334  female   NaN      0  PC 17611  133.6500              NaN   S    1
# 369  female  24.0      0  PC 17477   69.3000              B35   C    0
# 373    male  22.0      0  PC 17760  135.6333              NaN   C    0
# 375  female   NaN      0  PC 17604   82.1708              NaN   C    1
# 380  female  42.0      0  PC 17757  227.5250              NaN   C    0
# 493    male  71.0      0  PC 17609   49.5042              NaN   C    0
# 505    male  18.0      0  PC 17758  108.9000              C65   C    1
# 512    male  36.0      0  PC 17473   26.2875              E25   S    0
# 513  female  54.0      0  PC 17603   59.4000              NaN   C    1
# 527    male   NaN      0  PC 17483  221.7792              C95   S    0
# 537  female  30.0      0  PC 17761  106.4250              NaN   C    0
# 544    male  50.0      0  PC 17761  106.4250              C86   C    1
# 557    male   NaN      0  PC 17757  227.5250              NaN   C    0
# 572    male  36.0      0  PC 17474   26.3875              E25   S    0
# 599    male  49.0      0  PC 17485   56.9292              A20   C    1
# 609  female  40.0      0  PC 17582  153.4625             C125   S    0
# 641  female  24.0      0  PC 17477   69.3000              B35   C    0
# 645    male  48.0      0  PC 17572   76.7292              D33   C    1
# 660    male  50.0      0  PC 17611  133.6500              NaN   S    2
# 679    male  36.0      1  PC 17755  512.3292      B51 B53 B55   C    1
# 681    male  27.0      0  PC 17572   76.7292              D49   C    0
# 700  female  18.0      0  PC 17757  227.5250          C62 C64   C    1
# 701    male  35.0      0  PC 17475   26.2875              E24   S    0
# 707    male  42.0      0  PC 17476   26.2875              E24   S    0
# 710  female  24.0      0  PC 17482   49.5042              C90   C    0
# 716  female  38.0      0  PC 17757  227.5250              C45   C    0
# 737    male  35.0      0  PC 17755  512.3292             B101   C    0
# 742  female  21.0      2  PC 17608  262.3750  B57 B59 B63 B66   C    4
# 789    male  46.0      0  PC 17593   79.2000          B82 B84   C    0
# 793    male   NaN      0  PC 17600   30.6958              NaN   C    0
# 835  female  39.0      1  PC 17756   83.1583              E49   C    2
# 853  female  16.0      1  PC 17592   39.4000              D28   S    1
# 867    male  31.0      0  PC 17590   50.4958              A24   S    0

# %%
df[df['티켓번호'].str.contains("C.A")]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 33    짝수                              Wheadon, Mr. Edward H     0     2
# 56    홀수                                  Rugg, Miss. Emily     1     2
# 58    홀수                       West, Miss. Constance Mirium     1     2
# 66    홀수                       Nye, Mrs. (Elizabeth Ramell)     1     2
# 70    홀수                         Jenkin, Mr. Stephen Curnow     0     2
# 93    짝수                            Dean, Mr. Bertram Frank     0     3
# 134   홀수                     Sobey, Mr. Samuel James Hayden     0     2
# 145   짝수                       Nicholls, Mr. Joseph Charles     0     2
# 161   짝수  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...     1     2
# 234   홀수                  Leyson, Mr. Robert William Norman     0     2
# 237   짝수                   Collyer, Miss. Marjorie "Lottie"     1     2
# 265   짝수                                  Reeves, Mr. David     0     2
# 279   짝수                   Abbott, Mrs. Stanton (Rosa Hunt)     1     3
# 348   홀수             Coutts, Master. William Loch "William"     1     3
# 432   홀수  Louch, Mrs. Charles Alexander (Alice Adelaide ...     1     2
# 439   짝수             Kvillner, Mr. Johan Henrik Johannesson     0     2
# 450   홀수                              West, Mr. Edwy Arthur     0     2
# 472   홀수            West, Mrs. Edwy Arthur (Ada Mary Worth)     1     2
# 473   짝수       Jerwan, Mrs. Amin S (Marie Marthe Thuillard)     1     2
# 489   짝수              Coutts, Master. Eden Leslie "Neville"     1     3
# 497   짝수                    Shellard, Mr. Frederick William     0     3
# 516   홀수                       Lemore, Mrs. (Amelia Milley)     1     2
# 549   짝수                     Davies, Master. John Morgan Jr     1     2
# 594   홀수                            Chapman, Mr. John Henry     0     2
# 637   짝수                                Collyer, Mr. Harvey     0     2
# 672   홀수                        Mitchell, Mr. Henry Michael     0     2
# 746   홀수                        Abbott, Mr. Rossmore Edward     0     3
# 788   홀수                         Dean, Master. Bertram Vere     1     3
# 801   짝수        Collyer, Mrs. Harvey (Charlotte Annie Tate)     1     2
# 845   짝수                                Abbing, Mr. Anthony     0     3
# 883   짝수                      Banfield, Mr. Frederick James     0     2
#
#          성별    나이  부모자식수              티켓번호     티켓가격 선실번호 목적지  가족수
# 33     male  66.0      0        C.A. 24579  10.5000  NaN   S    0
# 56   female  21.0      0        C.A. 31026  10.5000  NaN   S    0
# 58   female   5.0      2        C.A. 34651  27.7500  NaN   S    3
# 66   female  29.0      0        C.A. 29395  10.5000  F33   S    0
# 70     male  32.0      0        C.A. 33111  10.5000  NaN   S    0
# 93     male  26.0      2         C.A. 2315  20.5750  NaN   S    3
# 134    male  25.0      0        C.A. 29178  13.0000  NaN   S    0
# 145    male  19.0      1        C.A. 33112  36.7500  NaN   S    2
# 161  female  40.0      0        C.A. 33595  15.7500  NaN   S    0
# 234    male  24.0      0        C.A. 29566  10.5000  NaN   S    0
# 237  female   8.0      2        C.A. 31921  26.2500  NaN   S    2
# 265    male  36.0      0        C.A. 17248  10.5000  NaN   S    0
# 279  female  35.0      1         C.A. 2673  20.2500  NaN   S    2
# 348    male   3.0      1        C.A. 37671  15.9000  NaN   S    2
# 432  female  42.0      0        SC/AH 3085  26.0000  NaN   S    1
# 439    male  31.0      0        C.A. 18723  10.5000  NaN   S    0
# 450    male  36.0      2        C.A. 34651  27.7500  NaN   S    3
# 472  female  33.0      2        C.A. 34651  27.7500  NaN   S    3
# 473  female  23.0      0   SC/AH Basle 541  13.7917    D   C    0
# 489    male   9.0      1        C.A. 37671  15.9000  NaN   S    2
# 497    male   NaN      0         C.A. 6212  15.1000  NaN   S    0
# 516  female  34.0      0        C.A. 34260  10.5000  F33   S    0
# 549    male   8.0      1        C.A. 33112  36.7500  NaN   S    2
# 594    male  37.0      0       SC/AH 29037  26.0000  NaN   S    1
# 637    male  31.0      1        C.A. 31921  26.2500  NaN   S    2
# 672    male  70.0      0        C.A. 24580  10.5000  NaN   S    0
# 746    male  16.0      1         C.A. 2673  20.2500  NaN   S    2
# 788    male   1.0      2         C.A. 2315  20.5750  NaN   S    3
# 801  female  31.0      1        C.A. 31921  26.2500  NaN   S    2
# 845    male  42.0      0         C.A. 5547   7.5500  NaN   S    0
# 883    male  28.0      0  C.A./SOTON 34068  10.5000  NaN   S    0

# %% [markdown]
# # 판다스 1일차 끝

# %% [markdown]
# # 판다스 2일차 시작

# %% [markdown]
# * 승객이름에서 () 없애기
# * 반복문/리스트표현식을 이용해 없애기
# * apply + lamda 함수를 이용해 없애기
# * .str 메서드를 이용해서 없애기

# %%
df['이름']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: 이름, Length: 891, dtype: object

# %%
# 반복문 + replace를 통해 () 없애기
result = []
for name in df['이름']:
#     print(name, type(name))
    result.append(name.replace("(", "").replace(")",""))
result
df['이름'] = result

# %%
# 괄호가 모두 사라졌음을 알 수 있다
df['이름']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: 이름, Length: 891, dtype: object

# %%
df = pd.read_csv("./data/Taitanic_train.csv")
df

# %%
df2 = df.copy()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ####  apply + lamda 함수를 이용해 없애기

# %%
# %%time
df['Name'].apply(lambda name: name.replace("(", "").replace(")", ""))
# Out:
# CPU times: total: 0 ns
# Wall time: 491 µs
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# #### .str.replace를 활용해서 처리하기

# %%
# %%time
df['Name'].str.replace("(", "").str.replace(")", "")
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### .str. 문자열함수 (upper, lower, split, join, strip)
# * 가장 편리하다

# %%
# 데이터타입이 다르다 *항상 데이터타입을 찍어보자
print(type(df['Name']))
print(type(df['Name'][0]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'str'>

# %%
# 안 먹힌다
df['Name'][0].replace("(", "")
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df['Name'].str.replace("(", "").str.replace(")", "")
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# 리스트로 나누기
df['Name'] = df['Name'].str.split()

# %%
df['Name']
# Out:
# 0                           [Braund,, Mr., Owen, Harris]
# 1      [Cumings,, Mrs., John, Bradley, (Florence, Bri...
# 2                             [Heikkinen,, Miss., Laina]
# 3      [Futrelle,, Mrs., Jacques, Heath, (Lily, May, ...
# 4                          [Allen,, Mr., William, Henry]
#                              ...
# 886                            [Montvila,, Rev., Juozas]
# 887                    [Graham,, Miss., Margaret, Edith]
# 888       [Johnston,, Miss., Catherine, Helen, "Carrie"]
# 889                           [Behr,, Mr., Karl, Howell]
# 890                              [Dooley,, Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
# 다시 합치기
df['Name'] = df['Name'].str.join(" ")

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# 이름만 가져오기
df['Name'] = df['Name'].str.split(", ")

# %%
df['Name'].apply(lambda x: x[0])
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
df['first_name'] = df['Name'].apply(lambda x: x[0])
df['second_name'] = df['Name'].apply(lambda x: x[1])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                            [Braund, Mr. Owen Harris]    male  22.0      1
# 1    [Cumings, Mrs. John Bradley (Florence Briggs T...  female  38.0      1
# 2                             [Heikkinen, Miss. Laina]  female  26.0      0
# 3       [Futrelle, Mrs. Jacques Heath (Lily May Peel)]  female  35.0      1
# 4                           [Allen, Mr. William Henry]    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                            [Montvila, Rev. Juozas]    male  27.0      0
# 887                     [Graham, Miss. Margaret Edith]  female  19.0      0
# 888         [Johnston, Miss. Catherine Helen "Carrie"]  female   NaN      1
# 889                            [Behr, Mr. Karl Howell]    male  26.0      0
# 890                              [Dooley, Mr. Patrick]    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked first_name  \
# 0        0         A/5 21171   7.2500   NaN        S     Braund
# 1        0          PC 17599  71.2833   C85        C    Cumings
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3        0            113803  53.1000  C123        S   Futrelle
# 4        0            373450   8.0500   NaN        S      Allen
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S   Montvila
# 887      0            112053  30.0000   B42        S     Graham
# 888      2        W./C. 6607  23.4500   NaN        S   Johnston
# 889      0            111369  30.0000  C148        C       Behr
# 890      0            370376   7.7500   NaN        Q     Dooley
#
#                                     second_name
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# 3            Mrs. Jacques Heath (Lily May Peel)
# 4                             Mr. William Henry
# ..                                          ...
# 886                                 Rev. Juozas
# 887                        Miss. Margaret Edith
# 888              Miss. Catherine Helen "Carrie"
# 889                             Mr. Karl Howell
# 890                                 Mr. Patrick
#
# [891 rows x 14 columns]

# %% [markdown]
# # groupby
# * 특정 기준 컬럼 지정해서 다른 컬럼의 통계량 (평균, 최소, 최대)
# * df[['보고싶은 컬럼1', '보고싶은 컬럼2']].groupby('기준컬럼').집합함수(mean, max, min, median, count)

# %% [markdown]
# * 성별별 생존자 수

# %%
survbysex = df[['Sex', 'Survived']].groupby(['Sex']).value_counts(sort=False)
survbysex
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
print(type(survbysex))
# Out:
# <class 'pandas.core.series.Series'>

# %%
survbysex.index
# Out:
# MultiIndex([('female', 0),
#             ('female', 1),
#             (  'male', 0),
#             (  'male', 1)],
#            names=['Sex', 'Survived'])

# %%
df3 = pd.DataFrame(survbysex)
df3
# Out:
#                  count
# Sex    Survived
# female 0            81
#        1           233
# male   0           468
#        1           109

# %%
233 / (81+233) * 100
# Out:
# 74.20382165605095

# %%
109 / (468+109) * 100
# Out:
# 18.890814558058924

# %%
18.890814558058924 / 74.20382165605095
# Out:
# 0.2545800760184765

# %% [markdown]
# 선실등급별 생존자 수

# %%
df[['Pclass', 'Survived']].groupby('Pclass').value_counts(sort=False)
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %% [markdown]
# 성별별, 선실등급 별 생존자수

# %%
df[['Sex', 'Pclass', 'Survived']].groupby(['Sex', 'Pclass']).value_counts(sort=False)
# Out:
# Sex     Pclass  Survived
# female  1       0             3
#                 1            91
#         2       0             6
#                 1            70
#         3       0            72
#                 1            72
# male    1       0            77
#                 1            45
#         2       0            91
#                 1            17
#         3       0           300
#                 1            47
# Name: count, dtype: int64

# %% [markdown]
# 은행 고객 등급
# - 급여 통장 입금여부, 액수
# - 적금, 예금

# %% [markdown]
# * 성별에 따른 나이의 평균, 최소, 최대값

# %%
df[['Sex', 'Age']].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
df[['Sex', 'Age']].groupby('Sex').min()
# Out:
#          Age
# Sex
# female  0.75
# male    0.42

# %%
df[['Sex', 'Age']].groupby('Sex').max()
# Out:
#          Age
# Sex
# female  63.0
# male    80.0

# %%
df[['Sex', 'Age']].groupby('Sex').agg(['min', 'max', 'mean'])
# Out:
#          Age
#          min   max       mean
# Sex
# female  0.75  63.0  27.915709
# male    0.42  80.0  30.726645

# %% [markdown]
# * 피벗테이블 pivot

# %%
df.pivot_table(values="Survived", index="Sex", columns="Pclass")
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # 결측값 찾기(값이 없는 것)

# %% [markdown]
# isna() 결측값인지 아닌지 확인 -> True(1), False(0) -> sum(결측값의 개수)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# first_name       0
# second_name      0
# dtype: int64

# %%
df.isna().sum() / len(df) * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# first_name      0.000000
# second_name     0.000000
# dtype: float64

# %% [markdown]
# dropna() 결측값이 있는 행을 삭제

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    [Cumings, Mrs. John Bradley (Florence Briggs T...  female  38.0      1
# 3       [Futrelle, Mrs. Jacques Heath (Lily May Peel)]  female  35.0      1
# 6                            [McCarthy, Mr. Timothy J]    male  54.0      0
# 10                   [Sandstrom, Miss. Marguerite Rut]  female   4.0      1
# 11                          [Bonnell, Miss. Elizabeth]  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871  [Beckwith, Mrs. Richard Leonard (Sallie Monype...  female  47.0      1
# 872                         [Carlsson, Mr. Frans Olof]    male  33.0      0
# 879    [Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)]  female  56.0      0
# 887                     [Graham, Miss. Margaret Edith]  female  19.0      0
# 889                            [Behr, Mr. Karl Howell]    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked first_name  \
# 1        0  PC 17599  71.2833          C85        C    Cumings
# 3        0    113803  53.1000         C123        S   Futrelle
# 6        0     17463  51.8625          E46        S   McCarthy
# 10       1   PP 9549  16.7000           G6        S  Sandstrom
# 11       0    113783  26.5500         C103        S    Bonnell
# ..     ...       ...      ...          ...      ...        ...
# 871      1     11751  52.5542          D35        S   Beckwith
# 872      0       695   5.0000  B51 B53 B55        S   Carlsson
# 879      1     11767  83.1583          C50        C     Potter
# 887      0    112053  30.0000          B42        S     Graham
# 889      0    111369  30.0000         C148        C       Behr
#
#                                     second_name
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 3            Mrs. Jacques Heath (Lily May Peel)
# 6                                 Mr. Timothy J
# 10                         Miss. Marguerite Rut
# 11                              Miss. Elizabeth
# ..                                          ...
# 871      Mrs. Richard Leonard (Sallie Monypeny)
# 872                              Mr. Frans Olof
# 879       Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887                        Miss. Margaret Edith
# 889                             Mr. Karl Howell
#
# [183 rows x 14 columns]

# %% [markdown]
# fillna() 결측값을 다른 값으로 채워주는 함수

# %%
round(df['Age'].mean())
# Out:
# 30

# %%
df['Age'] = df['Age'].fillna(round(df['Age'].mean()))

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# first_name       0
# second_name      0
# dtype: int64

# %%
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 여러개의 데이터프레임 합치기
# * concat: 두 개의 데이터 프레임을 1개로 합침
# * merge: sql join과 같은 역할 공통된 기준 컬럼 매칭해서 합침
# * join: sql join과 같은 역할 index가 같은 것끼리 합침

# %%
from sqlalchemy import create_engine
import  pymysql
pymysql.install_as_MySQLdb
# Out:
# <function pymysql.install_as_MySQLdb()>

# %%
221.155.18.165:3306

# %%
engine = create_engine("mysql+pymysql://kict01:kict01@221.155.18.165:3306/titanic")
conn = engine.connect()

# %%
passenger = pd.read_sql("p_info", con=conn)
ticket = pd.read_sql("t_info", con=conn)
survived = pd.read_sql("survived", con=conn)
conn.close()

# %%
passenger.head(1)
# Out:
#    PassengerId                     Name   Sex   Age  SibSp  Parch
# 0            1  Braund, Mr. Owen Harris  male  22.0      1      0

# %%
ticket.head(1)
# Out:
#    PassengerId     Ticket  Pclass  Fare Cabin Embarked
# 0            1  A/5 21171       3  7.25  None        S

# %%
survived.head(1)
# Out:
#    PassengerId  Survived
# 0            1         0

# %% [markdown]
# ## concat axis=0 행 추가, axis=1 열 추가
# * 기준 컬럼 없이 무조건 합침
# * 기본값은 행방향으로 합쳐줌
# * 옆으로 붙이고 싶으면 axis=1

# %%
print("passenger", passenger.shape)
print("ticket", ticket.shape)
print("survived", survived.shape)
# Out:
# passenger (891, 6)
# ticket (891, 6)
# survived (891, 2)

# %%
df1 = pd.concat([passenger, ticket, survived], axis=1)
df1
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch  PassengerId            Ticket  Pclass     Fare Cabin  \
# 0    22.0      1      0            1         A/5 21171       3   7.2500  None
# 1    38.0      1      0            2          PC 17599       1  71.2833   C85
# 2    26.0      0      0            3  STON/O2. 3101282       3   7.9250  None
# 3    35.0      1      0            4            113803       1  53.1000  C123
# 4    35.0      0      0            5            373450       3   8.0500  None
# ..    ...    ...    ...          ...               ...     ...      ...   ...
# 886  27.0      0      0          887            211536       2  13.0000  None
# 887  19.0      0      0          888            112053       1  30.0000   B42
# 888   NaN      1      2          889        W./C. 6607       3  23.4500  None
# 889  26.0      0      0          890            111369       1  30.0000  C148
# 890  32.0      0      0          891            370376       3   7.7500  None
#
#     Embarked  PassengerId  Survived
# 0          S            1         0
# 1          C            2         1
# 2          S            3         1
# 3          S            4         1
# 4          S            5         0
# ..       ...          ...       ...
# 886        S          887         0
# 887        S          888         1
# 888        S          889         0
# 889        C          890         1
# 890        Q          891         0
#
# [891 rows x 14 columns]

# %%
df_0 = pd.concat([passenger, ticket, survived], axis=0)
df_0.iloc[890:893, :]
# Out:
#      PassengerId                 Name   Sex   Age  SibSp  Parch     Ticket  \
# 890          891  Dooley, Mr. Patrick  male  32.0    0.0    0.0        NaN
# 0              1                  NaN   NaN   NaN    NaN    NaN  A/5 21171
# 1              2                  NaN   NaN   NaN    NaN    NaN   PC 17599
#
#      Pclass     Fare Cabin Embarked  Survived
# 890     NaN      NaN   NaN      NaN       NaN
# 0       3.0   7.2500  None        S       NaN
# 1       1.0  71.2833   C85        C       NaN

# %%
df_0
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                                                NaN     NaN
# 887          888                                                NaN     NaN
# 888          889                                                NaN     NaN
# 889          890                                                NaN     NaN
# 890          891                                                NaN     NaN
#
#       Age  SibSp  Parch Ticket  Pclass  Fare Cabin Embarked  Survived
# 0    22.0    1.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# 1    38.0    1.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# 2    26.0    0.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# 3    35.0    1.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# 4    35.0    0.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# ..    ...    ...    ...    ...     ...   ...   ...      ...       ...
# 886   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       0.0
# 887   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       1.0
# 888   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       0.0
# 889   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       1.0
# 890   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       0.0
#
# [2673 rows x 12 columns]

# %%
passenger.head(1)
# Out:
#    PassengerId                     Name   Sex   Age  SibSp  Parch
# 0            1  Braund, Mr. Owen Harris  male  22.0      1      0

# %%
ticket.head(1)
# Out:
#    PassengerId     Ticket  Pclass  Fare Cabin Embarked
# 0            1  A/5 21171       3  7.25  None        S

# %% [markdown]
# SQL문법: select * from passenger left join ticket on passenger.PassengerId = ticket.PassengerId

# %% [markdown]
# **PANDAS 문법: pd.merge(passenger, ticket, how="inner", on="PassengerId")**

# %%
joined_df = pd.merge(passenger, ticket, how="inner", on="PassengerId")

# %%
joined_df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171       3   7.2500  None        S
# 1    38.0      1      0          PC 17599       1  71.2833   C85        C
# 2    26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3    35.0      1      0            113803       1  53.1000  C123        S
# 4    35.0      0      0            373450       3   8.0500  None        S
# ..    ...    ...    ...               ...     ...      ...   ...      ...
# 886  27.0      0      0            211536       2  13.0000  None        S
# 887  19.0      0      0            112053       1  30.0000   B42        S
# 888   NaN      1      2        W./C. 6607       3  23.4500  None        S
# 889  26.0      0      0            111369       1  30.0000  C148        C
# 890  32.0      0      0            370376       3   7.7500  None        Q
#
# [891 rows x 11 columns]

# %%
joined_df = pd.merge(joined_df, survived, how="inner", on="PassengerId")
joined_df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# 0    22.0      1      0         A/5 21171       3   7.2500  None        S
# 1    38.0      1      0          PC 17599       1  71.2833   C85        C
# 2    26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3    35.0      1      0            113803       1  53.1000  C123        S
# 4    35.0      0      0            373450       3   8.0500  None        S
# ..    ...    ...    ...               ...     ...      ...   ...      ...
# 886  27.0      0      0            211536       2  13.0000  None        S
# 887  19.0      0      0            112053       1  30.0000   B42        S
# 888   NaN      1      2        W./C. 6607       3  23.4500  None        S
# 889  26.0      0      0            111369       1  30.0000  C148        C
# 890  32.0      0      0            370376       3   7.7500  None        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %% [markdown]
# # join: sql의 join과 같음, index명을 기준으로 합침

# %%
passenger = passenger.set_index("PassengerId")

# %%
passenger
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch
# PassengerId
# 1                1      0
# 2                1      0
# 3                0      0
# 4                1      0
# 5                0      0
# ...            ...    ...
# 887              0      0
# 888              0      0
# 889              1      2
# 890              0      0
# 891              0      0
#
# [891 rows x 5 columns]

# %%
ticket = ticket.set_index("PassengerId")

# %%
ticket
# Out:
#                        Ticket  Pclass     Fare Cabin Embarked
# PassengerId
# 1                   A/5 21171       3   7.2500  None        S
# 2                    PC 17599       1  71.2833   C85        C
# 3            STON/O2. 3101282       3   7.9250  None        S
# 4                      113803       1  53.1000  C123        S
# 5                      373450       3   8.0500  None        S
# ...                       ...     ...      ...   ...      ...
# 887                    211536       2  13.0000  None        S
# 888                    112053       1  30.0000   B42        S
# 889                W./C. 6607       3  23.4500  None        S
# 890                    111369       1  30.0000  C148        C
# 891                    370376       3   7.7500  None        Q
#
# [891 rows x 5 columns]

# %%
passenger.join(ticket)
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171       3   7.2500  None        S
# 2                1      0          PC 17599       1  71.2833   C85        C
# 3                0      0  STON/O2. 3101282       3   7.9250  None        S
# 4                1      0            113803       1  53.1000  C123        S
# 5                0      0            373450       3   8.0500  None        S
# ...            ...    ...               ...     ...      ...   ...      ...
# 887              0      0            211536       2  13.0000  None        S
# 888              0      0            112053       1  30.0000   B42        S
# 889              1      2        W./C. 6607       3  23.4500  None        S
# 890              0      0            111369       1  30.0000  C148        C
# 891              0      0            370376       3   7.7500  None        Q
#
# [891 rows x 10 columns]

# %%
joined_df2 = passenger.join(ticket)
joined_df2
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171       3   7.2500  None        S
# 2                1      0          PC 17599       1  71.2833   C85        C
# 3                0      0  STON/O2. 3101282       3   7.9250  None        S
# 4                1      0            113803       1  53.1000  C123        S
# 5                0      0            373450       3   8.0500  None        S
# ...            ...    ...               ...     ...      ...   ...      ...
# 887              0      0            211536       2  13.0000  None        S
# 888              0      0            112053       1  30.0000   B42        S
# 889              1      2        W./C. 6607       3  23.4500  None        S
# 890              0      0            111369       1  30.0000  C148        C
# 891              0      0            370376       3   7.7500  None        Q
#
# [891 rows x 10 columns]

# %%
survived = survived.set_index("PassengerId")

# %%
survived
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0
# ...               ...
# 887                 0
# 888                 1
# 889                 0
# 890                 1
# 891                 0
#
# [891 rows x 1 columns]

# %%
joined_df2 = joined_df2.join(survived)
joined_df2
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171       3   7.2500  None        S
# 2                1      0          PC 17599       1  71.2833   C85        C
# 3                0      0  STON/O2. 3101282       3   7.9250  None        S
# 4                1      0            113803       1  53.1000  C123        S
# 5                0      0            373450       3   8.0500  None        S
# ...            ...    ...               ...     ...      ...   ...      ...
# 887              0      0            211536       2  13.0000  None        S
# 888              0      0            112053       1  30.0000   B42        S
# 889              1      2        W./C. 6607       3  23.4500  None        S
# 890              0      0            111369       1  30.0000  C148        C
# 891              0      0            370376       3   7.7500  None        Q
#
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0
# ...               ...
# 887                 0
# 888                 1
# 889                 0
# 890                 1
# 891                 0
#
# [891 rows x 11 columns]

# %%
joined_df2 = joined_df2.reset_index()
joined_df2
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# 0    22.0      1      0         A/5 21171       3   7.2500  None        S
# 1    38.0      1      0          PC 17599       1  71.2833   C85        C
# 2    26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3    35.0      1      0            113803       1  53.1000  C123        S
# 4    35.0      0      0            373450       3   8.0500  None        S
# ..    ...    ...    ...               ...     ...      ...   ...      ...
# 886  27.0      0      0            211536       2  13.0000  None        S
# 887  19.0      0      0            112053       1  30.0000   B42        S
# 888   NaN      1      2        W./C. 6607       3  23.4500  None        S
# 889  26.0      0      0            111369       1  30.0000  C148        C
# 890  32.0      0      0            370376       3   7.7500  None        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %% [markdown]
# # 중복여부 확인 및 제거하기

# %%
toss = pd.read_csv("./data/viva_republica_toss.csv", index_col=0)
toss
# Out:
#             사용자  별점                                                 리뷰  \
# 0      Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1           최유연   1  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2       EXPRESS   1  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3          JS P   1  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4      AndPeter   1  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ...         ...  ..                                                ...
# 52560       나명자   5  사용은 편해요. 계좌개설 확인증이나 송금확인증 의 글씨가 좀 더 컸으면 좋겠습니다....
# 52561       김주영   4  소비 관리하는 데 아주 유용하게 쓰고 있습니다. ktx 예매 때문에 코레일을 이용했...
# 52562     bk im   1  편리함은 사라지고 불편함만 가중되고있음. 1. 동영상 광고 도입으로 토스 켤 때 마...
# 52563       임혜란   2  토스 편해서 사용했는데..최근에 토스에서 하는 꽃돼지이벤트 하다가 짜증났어요. 완전...
# 52564      60 2   3  왜 알람이 안 울릴까요? 입출금 알람 설정해뒀는데 어느 순간부터 안 울리네요 그렇다...
#
#                   날짜                                             개발자 응답
# 0      2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 1       2025년 1월 18일  안녕하세요. 최유연 님, 토스팀입니다. 토스증권 사용하시면서 주신 소중한 의견 너무...
# 2       2025년 2월 25일  안녕하세요. EXPRESS 님, 토스팀입니다. 우선 토스증권 이용에 불편을 드려 죄...
# 3       2025년 2월 28일  안녕하세요. JS P 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였...
# 4        2025년 3월 1일  안녕하세요. AndPeter 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ...              ...                                                ...
# 52560  2024년 10월 31일  안녕하세요. 나명자 님, 토스팀입니다. 토스를 이용하시면서 느끼신 소중한 의견을 주...
# 52561  2024년 11월 30일  안녕하세요. 김주영님, 토스팀입니다. 우선, 토스 이용에 불편을 드려 죄송합니다. ...
# 52562   2023년 7월 25일  안녕하세요. bk im님, 토스 고객센터입니다. 우선 많이 불편하셨음에도 시간내어 ...
# 52563   2025년 2월 27일  안녕하세요. 임혜란님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...
# 52564  2024년 11월 27일  안녕하세요. 고객 님, 토스팀입니다. 이용에 불편을 드린 것 같아 마음이 무겁습니다...
#
# [52565 rows x 5 columns]

# %%
toss.info
# Out:
# <bound method DataFrame.info of             사용자  별점                                                 리뷰  \
# 0      Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1           최유연   1  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2       EXPRESS   1  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3          JS P   1  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4      AndPeter   1  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ...         ...  ..                                                ...
# 52560       나명자   5  사용은 편해요. 계좌개설 확인증이나 송금확인증 의 글씨가 좀 더 컸으면 좋겠습니다....
# 52561       김주영   4  소비 관리하는 데 아주 유용하게 쓰고 있습니다. ktx 예매 때문에 코레일을 이용했...
# 52562     bk im   1  편리함은 사라지고 불편함만 가중되고있음. 1. 동영상 광고 도입으로 토스 켤 때 마...
# 52563       임혜란   2  토스 편해서 사용했는데..최근에 토스에서 하는 꽃돼지이벤트 하다가 짜증났어요. 완전...
# 52564      60 2   3  왜 알람이 안 울릴까요? 입출금 알람 설정해뒀는데 어느 순간부터 안 울리네요 그렇다...
#
#                   날짜                                             개발자 응답
# 0      2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 1       2025년 1월 18일  안녕하세요. 최유연 님, 토스팀입니다. 토스증권 사용하시면서 주신 소중한 의견 너무...
# 2       2025년 2월 25일  안녕하세요. EXPRESS 님, 토스팀입니다. 우선 토스증권 이용에 불편을 드려 죄...
# 3       2025년 2월 28일  안녕하세요. JS P 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였...
# 4        2025년 3월 1일  안녕하세요. AndPeter 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ...              ...                                                ...
# 52560  2024년 10월 31일  안녕하세요. 나명자 님, 토스팀입니다. 토스를 이용하시면서 느끼신 소중한 의견을 주...
# 52561  2024년 11월 30일  안녕하세요. 김주영님, 토스팀입니다. 우선, 토스 이용에 불편을 드려 죄송합니다. ...
# 52562   2023년 7월 25일  안녕하세요. bk im님, 토스 고객센터입니다. 우선 많이 불편하셨음에도 시간내어 ...
# 52563   2025년 2월 27일  안녕하세요. 임혜란님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...
# 52564  2024년 11월 27일  안녕하세요. 고객 님, 토스팀입니다. 이용에 불편을 드린 것 같아 마음이 무겁습니다...
#
# [52565 rows x 5 columns]>

# %%
toss[toss['사용자'] == "Won Choi"]
# Out:
#             사용자  별점                                                 리뷰  \
# 0      Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 20     Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 40     Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 60     Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 80     Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# ...         ...  ..                                                ...
# 50056  Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 50555  Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 51054  Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 51553  Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 52052  Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
#
#                   날짜                                             개발자 응답
# 0      2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 20     2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 40     2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 60     2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 80     2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ...              ...                                                ...
# 50056  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 50555  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 51054  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 51553  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 52052  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
#
# [203 rows x 5 columns]

# %%
toss.duplicated().sum()
# Out:
# np.int64(52052)

# %% [markdown]
# 중복 컬럼 삭제하기 drop_duplicates()

# %%
toss = toss.drop_duplicates()
toss
# Out:
#             사용자  별점                                                 리뷰  \
# 0      Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1           최유연   1  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2       EXPRESS   1  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3          JS P   1  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4      AndPeter   1  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ...         ...  ..                                                ...
# 52560       나명자   5  사용은 편해요. 계좌개설 확인증이나 송금확인증 의 글씨가 좀 더 컸으면 좋겠습니다....
# 52561       김주영   4  소비 관리하는 데 아주 유용하게 쓰고 있습니다. ktx 예매 때문에 코레일을 이용했...
# 52562     bk im   1  편리함은 사라지고 불편함만 가중되고있음. 1. 동영상 광고 도입으로 토스 켤 때 마...
# 52563       임혜란   2  토스 편해서 사용했는데..최근에 토스에서 하는 꽃돼지이벤트 하다가 짜증났어요. 완전...
# 52564      60 2   3  왜 알람이 안 울릴까요? 입출금 알람 설정해뒀는데 어느 순간부터 안 울리네요 그렇다...
#
#                   날짜                                             개발자 응답
# 0      2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 1       2025년 1월 18일  안녕하세요. 최유연 님, 토스팀입니다. 토스증권 사용하시면서 주신 소중한 의견 너무...
# 2       2025년 2월 25일  안녕하세요. EXPRESS 님, 토스팀입니다. 우선 토스증권 이용에 불편을 드려 죄...
# 3       2025년 2월 28일  안녕하세요. JS P 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였...
# 4        2025년 3월 1일  안녕하세요. AndPeter 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ...              ...                                                ...
# 52560  2024년 10월 31일  안녕하세요. 나명자 님, 토스팀입니다. 토스를 이용하시면서 느끼신 소중한 의견을 주...
# 52561  2024년 11월 30일  안녕하세요. 김주영님, 토스팀입니다. 우선, 토스 이용에 불편을 드려 죄송합니다. ...
# 52562   2023년 7월 25일  안녕하세요. bk im님, 토스 고객센터입니다. 우선 많이 불편하셨음에도 시간내어 ...
# 52563   2025년 2월 27일  안녕하세요. 임혜란님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...
# 52564  2024년 11월 27일  안녕하세요. 고객 님, 토스팀입니다. 이용에 불편을 드린 것 같아 마음이 무겁습니다...
#
# [513 rows x 5 columns]

# %%
toss = toss.reset_index(drop=True)

# %%
toss
# Out:
#           사용자  별점                                                 리뷰  \
# 0    Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1         최유연   1  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2     EXPRESS   1  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3        JS P   1  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4    AndPeter   1  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ..        ...  ..                                                ...
# 508       나명자   5  사용은 편해요. 계좌개설 확인증이나 송금확인증 의 글씨가 좀 더 컸으면 좋겠습니다....
# 509       김주영   4  소비 관리하는 데 아주 유용하게 쓰고 있습니다. ktx 예매 때문에 코레일을 이용했...
# 510     bk im   1  편리함은 사라지고 불편함만 가중되고있음. 1. 동영상 광고 도입으로 토스 켤 때 마...
# 511       임혜란   2  토스 편해서 사용했는데..최근에 토스에서 하는 꽃돼지이벤트 하다가 짜증났어요. 완전...
# 512      60 2   3  왜 알람이 안 울릴까요? 입출금 알람 설정해뒀는데 어느 순간부터 안 울리네요 그렇다...
#
#                 날짜                                             개발자 응답
# 0    2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 1     2025년 1월 18일  안녕하세요. 최유연 님, 토스팀입니다. 토스증권 사용하시면서 주신 소중한 의견 너무...
# 2     2025년 2월 25일  안녕하세요. EXPRESS 님, 토스팀입니다. 우선 토스증권 이용에 불편을 드려 죄...
# 3     2025년 2월 28일  안녕하세요. JS P 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였...
# 4      2025년 3월 1일  안녕하세요. AndPeter 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ..             ...                                                ...
# 508  2024년 10월 31일  안녕하세요. 나명자 님, 토스팀입니다. 토스를 이용하시면서 느끼신 소중한 의견을 주...
# 509  2024년 11월 30일  안녕하세요. 김주영님, 토스팀입니다. 우선, 토스 이용에 불편을 드려 죄송합니다. ...
# 510   2023년 7월 25일  안녕하세요. bk im님, 토스 고객센터입니다. 우선 많이 불편하셨음에도 시간내어 ...
# 511   2025년 2월 27일  안녕하세요. 임혜란님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...
# 512  2024년 11월 27일  안녕하세요. 고객 님, 토스팀입니다. 이용에 불편을 드린 것 같아 마음이 무겁습니다...
#
# [513 rows x 5 columns]
